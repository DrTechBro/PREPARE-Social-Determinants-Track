# %% [markdown]
# # Loading the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the CSV files into DataFrames
train_features = pd.read_csv('train_features.csv')
train_labels = pd.read_csv('train_labels.csv')

# Display the first few rows of the DataFrames
print(train_features.head())
print(train_labels.head())
# Out:
#     uid    age_03     urban_03  married_03  n_mar_03    edu_gru_03  \
# 0  aace       NaN          NaN         NaN       NaN           NaN
# 1  aanz       NaN          NaN         NaN       NaN           NaN
# 2  aape       NaN          NaN         NaN       NaN           NaN
# 3  aard  1. 50–59  1. 100,000+  3. Widowed       1.0  3. 7–9 years
# 4  ablr       NaN          NaN         NaN       NaN           NaN
#
#   n_living_child_03  migration_03 glob_hlth_03  adl_dress_03  ...  \
# 0               NaN           NaN          NaN           NaN  ...
# 1               NaN           NaN          NaN           NaN  ...
# 2               NaN           NaN          NaN           NaN  ...
# 3         1. 1 or 2           0.0      4. Fair           0.0  ...
# 4               NaN           NaN          NaN           NaN  ...
#
#             rrelgimp_12            rrfcntx_m_12              rsocact_m_12  \
# 0  2.somewhat important                 9.Never                   9.Never
# 1      1.very important                 9.Never        1.Almost every day
# 2  2.somewhat important  6.2 or 3 times a month  2.4 or more times a week
# 3      1.very important           4.Once a week                   9.Never
# 4      1.very important   3.2 or 3 times a week     3.2 or 3 times a week
#
#    rrelgwk_12  a16a_12  a21_12  a22_12  a33b_12  a34_12  \
# 0        0.No      NaN     NaN     NaN      NaN     NaN
# 1        0.No      NaN     NaN     NaN      NaN     NaN
# 2        0.No      NaN     NaN     NaN      NaN     NaN
# 3       1.Yes      NaN     NaN     NaN      NaN    No 2
# 4        0.No      NaN     NaN     NaN      NaN     NaN
#
#                               j11_12
# 0                         Concrete 2
# 1                         Concrete 2
# 2  Wood, mosaic, or other covering 1
# 3                         Concrete 2
# 4  Wood, mosaic, or other covering 1
#
# [5 rows x 184 columns]
#     uid  year  composite_score
# 0  aace  2021              175
# 1  aanz  2021              206
# 2  aape  2016              161
# 3  aape  2021              144
# 4  aard  2021              104

# %% [markdown]
# The dataset consists of two main files that we will be working with:
#
# 1. `train_features.csv`: Contains the predictors based on social determinants of health (SDOH) from the Mexican Health and Aging Study (MHAS). This file has 184 columns, including:
#
# - `uid`: Unique identifier for each individual.
# - Variables across years 2003 and 2012, with prefixes like age_03, urban_03, edu_gru_03, etc., representing different characteristics (age, urban status, marital status, education level, etc.).
# - Several columns appear to contain categorical data encoded with descriptors (e.g., "1. 50–59" for age, "3. Widowed" for marital status).
# - Many entries are marked as NaN, suggesting missing data for some individuals and variables.
#
# 2. `train_labels.csv`: Contains the target variable for prediction.
#
# - `uid`: Unique identifier matching those in train_features.
# - `year`: Year when the cognitive composite score was recorded (either 2016 or 2021).
# - `composite_score`: Cognitive composite score, representing the outcome we aim to predict.

# %%
train_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Columns: 184 entries, uid to j11_12
# dtypes: float64(140), object(44)
# memory usage: 4.6+ MB

# %% [markdown]
# `train_features` contains 3276 entries with 184 columns.

# %%
train_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4343 entries, 0 to 4342
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   uid              4343 non-null   object
#  1   year             4343 non-null   int64
#  2   composite_score  4343 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 101.9+ KB

# %% [markdown]
# `train_labels` contains 4334 entries with 3 columns.

# %%
# Checking if all uids in train_labels are present in train_features
missing_uids_in_features = set(train_labels['uid']) - set(train_features['uid'])

# Checking if there are duplicate uid-year pairs in train_labels which should be unique
duplicate_uid_year_pairs = train_labels.duplicated(subset=['uid', 'year']).sum()

# Results summary
missing_uids_in_features, duplicate_uid_year_pairs
# Out:
# (set(), 0)

# %% [markdown]
# Data Integrity Check Results
# 1. UID Consistency:
#
#     -All uid values in train_labels are present in train_features, confirming there are no missing individuals between the two datasets.
# 2. Unique UID-Year Pairs:
#
#     - No duplicate uid-year pairs in train_labels, ensuring that each UID-year combination corresponds to a unique cognitive score.

# %%
# Display column names in train_features to check for consistency in naming conventions
train_features.columns.tolist()
# Out:
# ['uid',
#  'age_03',
#  'urban_03',
#  'married_03',
#  'n_mar_03',
#  'edu_gru_03',
#  'n_living_child_03',
#  'migration_03',
#  'glob_hlth_03',
#  'adl_dress_03',
#  'adl_walk_03',
#  'adl_bath_03',
#  'adl_eat_03',
#  'adl_bed_03',
#  'adl_toilet_03',
#  'n_adl_03',
#  'iadl_money_03',
#  'iadl_meds_03',
#  'iadl_shop_03',
#  'iadl_meals_03',
#  'n_iadl_03',
#  'depressed_03',
#  'hard_03',
#  'restless_03',
#  'happy_03',
#  'lonely_03',
#  'enjoy_03',
#  'sad_03',
#  'tired_03',
#  'energetic_03',
#  'n_depr_03',
#  'cesd_depressed_03',
#  'hypertension_03',
#  'diabetes_03',
#  'resp_ill_03',
#  'arthritis_03',
#  'hrt_attack_03',
#  'stroke_03',
#  'cancer_03',
#  'n_illnesses_03',
#  'bmi_03',
#  'exer_3xwk_03',
#  'alcohol_03',
#  'tobacco_03',
#  'test_chol_03',
#  'test_tuber_03',
#  'test_diab_03',
#  'test_pres_03',
#  'hosp_03',
#  'visit_med_03',
#  'out_proc_03',
#  'visit_dental_03',
#  'imss_03',
#  'issste_03',
#  'pem_def_mar_03',
#  'insur_private_03',
#  'insur_other_03',
#  'insured_03',
#  'decis_famil_03',
#  'decis_personal_03',
#  'employment_03',
#  'age_12',
#  'urban_12',
#  'married_12',
#  'n_mar_12',
#  'edu_gru_12',
#  'n_living_child_12',
#  'migration_12',
#  'glob_hlth_12',
#  'adl_dress_12',
#  'adl_walk_12',
#  'adl_bath_12',
#  'adl_eat_12',
#  'adl_bed_12',
#  'adl_toilet_12',
#  'n_adl_12',
#  'iadl_money_12',
#  'iadl_meds_12',
#  'iadl_shop_12',
#  'iadl_meals_12',
#  'n_iadl_12',
#  'depressed_12',
#  'hard_12',
#  'restless_12',
#  'happy_12',
#  'lonely_12',
#  'enjoy_12',
#  'sad_12',
#  'tired_12',
#  'energetic_12',
#  'n_depr_12',
#  'cesd_depressed_12',
#  'hypertension_12',
#  'diabetes_12',
#  'resp_ill_12',
#  'arthritis_12',
#  'hrt_attack_12',
#  'stroke_12',
#  'cancer_12',
#  'n_illnesses_12',
#  'bmi_12',
#  'exer_3xwk_12',
#  'alcohol_12',
#  'tobacco_12',
#  'test_chol_12',
#  'test_tuber_12',
#  'test_diab_12',
#  'test_pres_12',
#  'hosp_12',
#  'visit_med_12',
#  'out_proc_12',
#  'visit_dental_12',
#  'imss_12',
#  'issste_12',
#  'pem_def_mar_12',
#  'insur_private_12',
#  'insur_other_12',
#  'insured_12',
#  'decis_famil_12',
#  'decis_personal_12',
#  'employment_12',
#  'vax_flu_12',
#  'vax_pneu_12',
#  'seg_pop_12',
#  'care_adult_12',
#  'care_child_12',
#  'volunteer_12',
#  'attends_class_12',
#  'attends_club_12',
#  'reads_12',
#  'games_12',
#  'table_games_12',
#  'comms_tel_comp_12',
#  'act_mant_12',
#  'tv_12',
#  'sewing_12',
#  'satis_ideal_12',
#  'satis_excel_12',
#  'satis_fine_12',
#  'cosas_imp_12',
#  'wouldnt_change_12',
#  'memory_12',
#  'ragender',
#  'rameduc_m',
#  'rafeduc_m',
#  'sgender_03',
#  'rjob_hrswk_03',
#  'rjlocc_m_03',
#  'rjob_end_03',
#  'rjobend_reason_03',
#  'rearnings_03',
#  'searnings_03',
#  'hincome_03',
#  'hinc_business_03',
#  'hinc_rent_03',
#  'hinc_assets_03',
#  'hinc_cap_03',
#  'rinc_pension_03',
#  'sinc_pension_03',
#  'rrelgimp_03',
#  'sgender_12',
#  'rjob_hrswk_12',
#  'rjlocc_m_12',
#  'rjob_end_12',
#  'rjobend_reason_12',
#  'rearnings_12',
#  'searnings_12',
#  'hincome_12',
#  'hinc_business_12',
#  'hinc_rent_12',
#  'hinc_assets_12',
#  'hinc_cap_12',
#  'rinc_pension_12',
#  'sinc_pension_12',
#  'rrelgimp_12',
#  'rrfcntx_m_12',
#  'rsocact_m_12',
#  'rrelgwk_12',
#  'a16a_12',
#  'a21_12',
#  'a22_12',
#  'a33b_12',
#  'a34_12',
#  'j11_12']

# %% [markdown]
# Column Naming Convention Observations
# 1. Year-Specific Suffixes:
#
#     - Most columns follow a convention where suffixes _03 and _12 indicate data collected in 2003 and 2012, respectively.
#     - Exceptions are columns like ragender, rameduc_m, and rafeduc_m (gender and parental education), which do not have year-specific suffixes, likely indicating they are static variables.
# 2. Underscore Separations:
#
#     - Column names generally use underscores (_) for separating words, making them consistent and readable. However, some columns use combined letters without separation (e.g., iadl_money_03 and adl_dress_03), which is still consistent across similar variables.
# 3. Mixed Naming for Health and Social Determinants:
#
#     - Variables related to health coverage (e.g., imss_03, issste_03) and household income sources (e.g., hincome_03, hinc_business_03) are consistently named with abbreviations followed by underscores and year suffixes.
#     - Social activities and lifestyle variables, such as vax_flu_12, attends_club_12, and rrfcntx_m_12, follow similar conventions, maintaining readability and consistency.

# %%
# Checking the proportion of missing values per column
missing_values_features = train_features.isnull().mean() * 100  # percentage of missing values in train_features
missing_values_labels = train_labels.isnull().mean() * 100      # percentage of missing values in train_labels

print(missing_values_features)
print(missing_values_labels)
# Out:
# uid            0.000000
# age_03        31.623932
# urban_03      31.562882
# married_03    31.562882
# n_mar_03      32.173382
#                 ...
# a21_12        98.717949
# a22_12        98.901099
# a33b_12       98.717949
# a34_12        35.531136
# j11_12         2.289377
# Length: 184, dtype: float64
# uid                0.0
# year               0.0
# composite_score    0.0
# dtype: float64

# %% [markdown]
# Missing values are prevalent across both years (2003 and 2012), with some variables (like a21_12 and a22_12) having over 98% missing values.
#
# High proportions of missing data suggest selective survey questions or responses

# %%
# Separating categorical and numerical columns in train_features
categorical_columns = train_features.select_dtypes(include=['object']).columns.tolist()
numerical_columns = train_features.select_dtypes(include=['float64', 'int64']).columns.tolist()

print(categorical_columns)
print(numerical_columns)

print(f"Number of categorical columns: {len(categorical_columns)}")
print(f"Number of numerical columns: {len(numerical_columns)}")
# Out:
# ['uid', 'age_03', 'urban_03', 'married_03', 'edu_gru_03', 'n_living_child_03', 'glob_hlth_03', 'bmi_03', 'decis_famil_03', 'employment_03', 'age_12', 'urban_12', 'married_12', 'edu_gru_12', 'n_living_child_12', 'glob_hlth_12', 'bmi_12', 'decis_famil_12', 'decis_personal_12', 'employment_12', 'satis_ideal_12', 'satis_excel_12', 'satis_fine_12', 'cosas_imp_12', 'wouldnt_change_12', 'memory_12', 'ragender', 'rameduc_m', 'rafeduc_m', 'sgender_03', 'rjlocc_m_03', 'rjobend_reason_03', 'rrelgimp_03', 'sgender_12', 'rjlocc_m_12', 'rjobend_reason_12', 'rrelgimp_12', 'rrfcntx_m_12', 'rsocact_m_12', 'rrelgwk_12', 'a22_12', 'a33b_12', 'a34_12', 'j11_12']
# ['n_mar_03', 'migration_03', 'adl_dress_03', 'adl_walk_03', 'adl_bath_03', 'adl_eat_03', 'adl_bed_03', 'adl_toilet_03', 'n_adl_03', 'iadl_money_03', 'iadl_meds_03', 'iadl_shop_03', 'iadl_meals_03', 'n_iadl_03', 'depressed_03', 'hard_03', 'restless_03', 'happy_03', 'lonely_03', 'enjoy_03', 'sad_03', 'tired_03', 'energetic_03', 'n_depr_03', 'cesd_depressed_03', 'hypertension_03', 'diabetes_03', 'resp_ill_03', 'arthritis_03', 'hrt_attack_03', 'stroke_03', 'cancer_03', 'n_illnesses_03', 'exer_3xwk_03', 'alcohol_03', 'tobacco_03', 'test_chol_03', 'test_tuber_03', 'test_diab_03', 'test_pres_03', 'hosp_03', 'visit_med_03', 'out_proc_03', 'visit_dental_03', 'imss_03', 'issste_03', 'pem_def_mar_03', 'insur_private_03', 'insur_other_03', 'insured_03', 'decis_personal_03', 'n_mar_12', 'migration_12', 'adl_dress_12', 'adl_walk_12', 'adl_bath_12', 'adl_eat_12', 'adl_bed_12', 'adl_toilet_12', 'n_adl_12', 'iadl_money_12', 'iadl_meds_12', 'iadl_shop_12', 'iadl_meals_12', 'n_iadl_12', 'depressed_12', 'hard_12', 'restless_12', 'happy_12', 'lonely_12', 'enjoy_12', 'sad_12', 'tired_12', 'energetic_12', 'n_depr_12', 'cesd_depressed_12', 'hypertension_12', 'diabetes_12', 'resp_ill_12', 'arthritis_12', 'hrt_attack_12', 'stroke_12', 'cancer_12', 'n_illnesses_12', 'exer_3xwk_12', 'alcohol_12', 'tobacco_12', 'test_chol_12', 'test_tuber_12', 'test_diab_12', 'test_pres_12', 'hosp_12', 'visit_med_12', 'out_proc_12', 'visit_dental_12', 'imss_12', 'issste_12', 'pem_def_mar_12', 'insur_private_12', 'insur_other_12', 'insured_12', 'vax_flu_12', 'vax_pneu_12', 'seg_pop_12', 'care_adult_12', 'care_child_12', 'volunteer_12', 'attends_class_12', 'attends_club_12', 'reads_12', 'games_12', 'table_games_12', 'comms_tel_comp_12', 'act_mant_12', 'tv_12', 'sewing_12', 'rjob_hrswk_03', 'rjob_end_03', 'rearnings_03', 'searnings_03', 'hincome_03', 'hinc_business_03', 'hinc_rent_03', 'hinc_assets_03', 'hinc_cap_03', 'rinc_pension_03', 'sinc_pension_03', 'rjob_hrswk_12', 'rjob_end_12', 'rearnings_12', 'searnings_12', 'hincome_12', 'hinc_business_12', 'hinc_rent_12', 'hinc_assets_12', 'hinc_cap_12', 'rinc_pension_12', 'sinc_pension_12', 'a16a_12', 'a21_12']
# Number of categorical columns: 44
# Number of numerical columns: 140

# %%
# Display unique values for each categorical column in train_features to understand the data entries better
unique_values_categorical = {col: train_features[col].unique() for col in categorical_columns}

unique_values_categorical
# Out:
# {'uid': array(['aace', 'aanz', 'aape', ..., 'zzci', 'zzjb', 'zzti'], dtype=object),
#  'age_03': array([nan, '1. 50–59', '3. 70–79', '2. 60–69', '0. 49 or younger',
#         '4. 80+'], dtype=object),
#  'urban_03': array([nan, '1. 100,000+', '0. <100,000'], dtype=object),
#  'married_03': array([nan, '3. Widowed', '1. Married or in civil union', '4. Single',
#         '2. Separated or divorced'], dtype=object),
#  'edu_gru_03': array([nan, '3. 7–9 years', '1. 1–5 years', '0. No education',
#         '2. 6 years', '4. 10+ years'], dtype=object),
#  'n_living_child_03': array([nan, '1. 1 or 2', '3. 5 or 6', '0. No children', '2. 3 or 4',
#         '4. 7+'], dtype=object),
#  'glob_hlth_03': array([nan, '4. Fair', '5. Poor', '3. Good', '1. Excellent',
#         '2. Very good'], dtype=object),
#  'bmi_03': array([nan, '3. Overweight', '4. Obese', '1. Underweight',
#         '2. Normal weight', '5. Morbidly obese'], dtype=object),
#  'decis_famil_03': array([nan, '2. Approximately equal weight', '1. Respondent', '3. Spouse'],
#        dtype=object),
#  'employment_03': array([nan, '3. Dedicated to household chores', '1. Currently Working',
#         '2. Currently looking for work',
#         '4. Retired, incapacitated, or does not work'], dtype=object),
#  'age_12': array(['2. 60–69', '1. 50–59', '4. 80+', '3. 70–79', nan,
#         '0. 49 or younger'], dtype=object),
#  'urban_12': array(['0. <100,000', '1. 100,000+', nan], dtype=object),
#  'married_12': array(['1. Married or in civil union', '3. Widowed',
#         '2. Separated or divorced', nan, '4. Single'], dtype=object),
#  'edu_gru_12': array(['0. No education', '3. 7–9 years', '1. 1–5 years', '2. 6 years',
#         '4. 10+ years', nan], dtype=object),
#  'n_living_child_12': array(['1. 1 or 2', '3. 5 or 6', '0. No children', '2. 3 or 4', '4. 7+',
#         nan], dtype=object),
#  'glob_hlth_12': array(['4. Fair', '3. Good', '2. Very good', '5. Poor', nan,
#         '1. Excellent'], dtype=object),
#  'bmi_12': array(['3. Overweight', '4. Obese', '2. Normal weight', nan,
#         '1. Underweight', '5. Morbidly obese'], dtype=object),
#  'decis_famil_12': array(['2. Approximately equal weight', '3. Spouse', nan, '1. Respondent'],
#        dtype=object),
#  'decis_personal_12': array(['1. A lot', '2. A little', nan, '3. None'], dtype=object),
#  'employment_12': array(['1. Currently Working', '2. Currently looking for work',
#         '3. Dedicated to household chores',
#         '4. Retired, incapacitated, or does not work', nan], dtype=object),
#  'satis_ideal_12': array(['3. Disagrees', '1. Agrees', '2. Neither agrees nor disagrees',
#         nan], dtype=object),
#  'satis_excel_12': array(['3. Disagrees', '2. Neither agrees nor disagrees', '1. Agrees',
#         nan], dtype=object),
#  'satis_fine_12': array(['1. Agrees', '3. Disagrees', '2. Neither agrees nor disagrees',
#         nan], dtype=object),
#  'cosas_imp_12': array(['1. Agrees', '2. Neither agrees nor disagrees', '3. Disagrees',
#         nan], dtype=object),
#  'wouldnt_change_12': array(['3. Disagrees', '1. Agrees', '2. Neither agrees nor disagrees',
#         nan], dtype=object),
#  'memory_12': array(['2. Very good', '4. Fair', '3. Good', nan, '5. Poor',
#         '1. Excellent'], dtype=object),
#  'ragender': array(['1.Man', '2.Woman'], dtype=object),
#  'rameduc_m': array(['1.None', '2.Some primary', '3.Primary', nan,
#         '4.More than primary'], dtype=object),
#  'rafeduc_m': array(['1.None', '2.Some primary', '4.More than primary', '3.Primary',
#         nan], dtype=object),
#  'sgender_03': array([nan, '2.Woman', '1.Man'], dtype=object),
#  'rjlocc_m_03': array([nan, '6.Workers in Agriculture, Livestock, Forestry, and Fishing',
#         '18.Safety and Security Personnel',
#         '15.Traveling Salespeople and Traveling Salespeople of Services',
#         '8.Artisans and Workers in Production, Repair, Maintenance',
#         '14.Merchants and Sales Representatives', '1.Professionals',
#         '17.Domestic Workers',
#         '9.Operators of Fixed Machinery and Equipment for Ind. Production',
#         '16.Workers in the Service Industry', '19.Other Workers',
#         '11.Drivers and Asst Drivers of Mobile Machinery and Transport Vehicles',
#         '10.Asst/Laborers etc in Ind. Production, Repair, Maintenance',
#         '13.Administrative Support Staff',
#         '4.Workers in Art, Shows, and Sports',
#         '5.Officials and Directors Public, Private, and Social Sectors',
#         '3.Educators', '2.Technicians',
#         '12.Department Heads/Coordinators/Supervisors in Admin and Service Activities'],
#        dtype=object),
#  'rjobend_reason_03': array([nan, '4.Health reason', '5.Family reason', '1.Retired', '8.Other',
#         '3.Laid off'], dtype=object),
#  'rrelgimp_03': array([nan, '1.very important', '2.somewhat important', '3.not important'],
#        dtype=object),
#  'sgender_12': array(['2.Woman', '1.Man', nan], dtype=object),
#  'rjlocc_m_12': array(['6.Workers in Agriculture, Livestock, Forestry, and Fishing',
#         '18.Safety and Security Personnel', nan,
#         '8.Artisans and Workers in Production, Repair, Maintenance',
#         '14.Merchants and Sales Representatives', '17.Domestic Workers',
#         '9.Operators of Fixed Machinery and Equipment for Ind. Production',
#         '15.Traveling Salespeople and Traveling Salespeople of Services',
#         '16.Workers in the Service Industry',
#         '4.Workers in Art, Shows, and Sports', '3.Educators',
#         '12.Department Heads/Coordinators/Supervisors in Admin and Service Activities',
#         '10.Asst/Laborers etc in Ind. Production, Repair, Maintenance',
#         '1.Professionals', '13.Administrative Support Staff',
#         '11.Drivers and Asst Drivers of Mobile Machinery and Transport Vehicles',
#         '7.Bosses/Supervisors etc in Artistic, Ind. Production, Repair, Maintenance Activities',
#         '2.Technicians',
#         '5.Officials and Directors Public, Private, and Social Sectors'],
#        dtype=object),
#  'rjobend_reason_12': array([nan, '8.Other', '3.Laid off', '4.Health reason', '5.Family reason',
#         '1.Retired'], dtype=object),
#  'rrelgimp_12': array(['2.somewhat important', '1.very important', '3.not important', nan],
#        dtype=object),
#  'rrfcntx_m_12': array(['9.Never', '6.2 or 3 times a month', '4.Once a week',
#         '3.2 or 3 times a week', '8.Almost Never, sporadic',
#         '1.Almost every day', '2.4 or more times a week', '7.Once a month',
#         nan, '5.4 or more times a month'], dtype=object),
#  'rsocact_m_12': array(['9.Never', '1.Almost every day', '2.4 or more times a week',
#         '3.2 or 3 times a week', '4.Once a week', '7.Once a month',
#         '8.Almost Never, sporadic', nan, '6.2 or 3 times a month',
#         '5.4 or more times a month'], dtype=object),
#  'rrelgwk_12': array(['0.No', '1.Yes', nan], dtype=object),
#  'a22_12': array([nan, 'Agriculture/ Animal breeding 01',
#         'Gardening or maintenance 03',
#         'Construction/ Manufacturing/ Mining 02', 'Did not work 08',
#         'Childcare or domestic work 04', 'Restaurant/ Store/ Hotel 05',
#         'Other 07'], dtype=object),
#  'a33b_12': array([nan, 'Neither 3', 'Permanent resident 1', 'Citizen 2'],
#        dtype=object),
#  'a34_12': array([nan, 'No 2', 'Yes 1'], dtype=object),
#  'j11_12': array(['Concrete 2', 'Wood, mosaic, or other covering 1', 'Mud 3', nan],
#        dtype=object)}

# %%
# Display unique values for each numerical column in train_features to understand the data entries better
unique_values_numerical = {col: train_features[col].unique() for col in numerical_columns}

unique_values_numerical
# Out:
# {'n_mar_03': array([nan,  1.,  2.,  3.,  0.,  4.,  5.]),
#  'migration_03': array([nan,  0.,  1.]),
#  'adl_dress_03': array([nan,  0.,  1.]),
#  'adl_walk_03': array([nan,  0.,  1.]),
#  'adl_bath_03': array([nan,  0.,  1.]),
#  'adl_eat_03': array([nan,  0.,  1.]),
#  'adl_bed_03': array([nan,  0.,  1.]),
#  'adl_toilet_03': array([nan,  0.,  1.]),
#  'n_adl_03': array([nan,  0.,  1.,  2.,  3.,  5.,  4.]),
#  'iadl_money_03': array([nan,  0.,  1.]),
#  'iadl_meds_03': array([nan,  0.,  1.]),
#  'iadl_shop_03': array([nan,  0.,  1.]),
#  'iadl_meals_03': array([nan,  0.,  1.]),
#  'n_iadl_03': array([nan,  0.,  1.,  3.,  2.,  4.]),
#  'depressed_03': array([nan,  1.,  0.]),
#  'hard_03': array([nan,  0.,  1.]),
#  'restless_03': array([nan,  1.,  0.]),
#  'happy_03': array([nan,  1.,  0.]),
#  'lonely_03': array([nan,  1.,  0.]),
#  'enjoy_03': array([nan,  1.,  0.]),
#  'sad_03': array([nan,  1.,  0.]),
#  'tired_03': array([nan,  1.,  0.]),
#  'energetic_03': array([nan,  0.,  1.]),
#  'n_depr_03': array([nan,  6.,  7.,  3.,  5.,  9.,  4.,  2.,  1.,  0.,  8.]),
#  'cesd_depressed_03': array([nan,  1.,  0.]),
#  'hypertension_03': array([nan,  0.,  1.]),
#  'diabetes_03': array([nan,  1.,  0.]),
#  'resp_ill_03': array([nan,  0.,  1.]),
#  'arthritis_03': array([nan,  0.,  1.]),
#  'hrt_attack_03': array([nan,  0.,  1.]),
#  'stroke_03': array([nan,  0.,  1.]),
#  'cancer_03': array([nan,  0.,  1.]),
#  'n_illnesses_03': array([nan,  1.,  0.,  3.,  2.,  4.,  5.]),
#  'exer_3xwk_03': array([nan,  1.,  0.]),
#  'alcohol_03': array([nan,  0.,  1.]),
#  'tobacco_03': array([nan,  0.,  1.]),
#  'test_chol_03': array([nan,  1.,  0.]),
#  'test_tuber_03': array([nan,  0.,  1.]),
#  'test_diab_03': array([nan,  1.,  0.]),
#  'test_pres_03': array([nan,  1.,  0.]),
#  'hosp_03': array([nan,  0.,  1.]),
#  'visit_med_03': array([nan,  1.,  0.]),
#  'out_proc_03': array([nan,  0.,  1.]),
#  'visit_dental_03': array([nan,  0.,  1.]),
#  'imss_03': array([nan,  0.,  1.]),
#  'issste_03': array([nan,  0.,  1.]),
#  'pem_def_mar_03': array([nan,  0.,  1.]),
#  'insur_private_03': array([nan,  0.,  1.]),
#  'insur_other_03': array([nan,  0.,  1.]),
#  'insured_03': array([nan,  0.,  1.]),
#  'decis_personal_03': array([nan,  1.,  2.,  3.]),
#  'n_mar_12': array([ 1.,  2.,  3.,  4., nan,  0.,  5.,  7.]),
#  'migration_12': array([ 0.,  1., nan]),
#  'adl_dress_12': array([ 0.,  1., nan]),
#  'adl_walk_12': array([nan,  0.,  1.]),
#  'adl_bath_12': array([nan,  0.,  1.]),
#  'adl_eat_12': array([nan,  0.,  1.]),
#  'adl_bed_12': array([nan,  0.,  1.]),
#  'adl_toilet_12': array([nan,  0.,  1.]),
#  'n_adl_12': array([nan,  0.,  1.,  3.,  2.,  5.,  4.]),
#  'iadl_money_12': array([ 0., nan,  1.]),
#  'iadl_meds_12': array([ 0., nan,  1.]),
#  'iadl_shop_12': array([ 0.,  1., nan]),
#  'iadl_meals_12': array([ 0., nan,  1.]),
#  'n_iadl_12': array([ 0.,  1., nan,  2.,  3.,  4.]),
#  'depressed_12': array([ 0.,  1., nan]),
#  'hard_12': array([ 0.,  1., nan]),
#  'restless_12': array([ 0.,  1., nan]),
#  'happy_12': array([ 1.,  0., nan]),
#  'lonely_12': array([ 0.,  1., nan]),
#  'enjoy_12': array([ 1.,  0., nan]),
#  'sad_12': array([ 0.,  1., nan]),
#  'tired_12': array([ 0.,  1., nan]),
#  'energetic_12': array([ 1.,  0., nan]),
#  'n_depr_12': array([ 0.,  4.,  8.,  5.,  3.,  7.,  6.,  1.,  2., nan,  9.]),
#  'cesd_depressed_12': array([ 0.,  1., nan]),
#  'hypertension_12': array([ 1.,  0., nan]),
#  'diabetes_12': array([ 0.,  1., nan]),
#  'resp_ill_12': array([ 0.,  1., nan]),
#  'arthritis_12': array([ 0.,  1., nan]),
#  'hrt_attack_12': array([ 0.,  1., nan]),
#  'stroke_12': array([ 0., nan,  1.]),
#  'cancer_12': array([ 0.,  1., nan]),
#  'n_illnesses_12': array([ 1.,  0.,  3.,  2., nan,  4.,  5.]),
#  'exer_3xwk_12': array([ 1.,  0., nan]),
#  'alcohol_12': array([ 0.,  1., nan]),
#  'tobacco_12': array([ 0.,  1., nan]),
#  'test_chol_12': array([ 0.,  1., nan]),
#  'test_tuber_12': array([ 0., nan,  1.]),
#  'test_diab_12': array([ 1.,  0., nan]),
#  'test_pres_12': array([ 1.,  0., nan]),
#  'hosp_12': array([ 0.,  1., nan]),
#  'visit_med_12': array([ 1.,  0., nan]),
#  'out_proc_12': array([ 0.,  1., nan]),
#  'visit_dental_12': array([ 0.,  1., nan]),
#  'imss_12': array([ 0.,  1., nan]),
#  'issste_12': array([ 0.,  1., nan]),
#  'pem_def_mar_12': array([ 0., nan,  1.]),
#  'insur_private_12': array([ 0.,  1., nan]),
#  'insur_other_12': array([ 1.,  0., nan]),
#  'insured_12': array([ 1.,  0., nan]),
#  'vax_flu_12': array([ 0.,  1., nan]),
#  'vax_pneu_12': array([ 0.,  1., nan]),
#  'seg_pop_12': array([ 1.,  0., nan]),
#  'care_adult_12': array([ 0.,  1., nan]),
#  'care_child_12': array([ 0.,  1., nan]),
#  'volunteer_12': array([ 0.,  1., nan]),
#  'attends_class_12': array([ 0.,  1., nan]),
#  'attends_club_12': array([ 0.,  1., nan]),
#  'reads_12': array([ 1.,  0., nan]),
#  'games_12': array([ 0.,  1., nan]),
#  'table_games_12': array([ 0.,  1., nan]),
#  'comms_tel_comp_12': array([ 0.,  1., nan]),
#  'act_mant_12': array([ 1.,  0., nan]),
#  'tv_12': array([ 1.,  0., nan]),
#  'sewing_12': array([ 0.,  1., nan]),
#  'rjob_hrswk_03': array([nan, 30., 48., 35.,  5., 72., 36., 42., 63., 45., 12.,  6., 40.,
#         55., 18., 57., 15., 60., 84., 39., 16., 21., 70., 56., 50., 20.,
#         66., 90., 49., 44., 47.,  9., 25., 99.,  4., 28., 87., 64., 77.,
#         52., 24., 54., 13., 46., 26., 14.,  7., 10., 94., 23., 81.,  3.,
#         68., 58., 71., 73., 76., 32., 38., 27., 91., 22.,  8., 74., 79.,
#         31., 80., 67., 62., 82., 65., 59., 29., 88., 85.,  1., 43., 78.,
#         34., 17., 53., 33., 19.]),
#  'rjob_end_03': array([  nan, 2003., 1973., 1967., 1993., 2001., 2002., 1953., 1991.,
#         1985., 2000., 1978., 1997., 1999., 1971., 1969., 1968., 1995.,
#         1996., 1998., 1958., 1986., 1983., 1972., 1988., 1981., 1951.,
#         1977., 1979., 1994., 1989., 1965., 1990., 1970., 1963., 1992.,
#         1974., 1941., 1982., 1960., 1980., 1987., 1943., 1976., 1961.,
#         1964., 1975., 1984., 1948.]),
#  'rearnings_03': array([    nan,      0.,  30000.,  19000.,  48000.,   6000., 108000.,
#          68000.,   8000.,  58000., 260000.,  26000.,  21000.,  52000.,
#          36000.,  12000.,  41000.,   5000.,  24000.,  25000.,  44000.,
#          50000., 130000.,  13000.,   3000.,  11000.,  35000., 112000.,
#          87000.,  39000.,  22000.,  56000.,  14000.,  98000.,  20000.,
#          17000.,  29000.,  38000.,  34000.,  10000.,  79000.,  51000.,
#          31000.,   7000.,  72000.,  54000.,  43000.,  65000.,  78000.,
#          60000.,  40000.,  63000., 100000., 198000.,  94000.,  49000.,
#          88000.,   4000.,  18000., 180000., 149000., 187000.,   9000.,
#          61000.,  76000.,  66000., 156000.,   1000.,  67000., 196000.,
#         216000., 159000., 222000., 102000.,  27000.,  16000.,  70000.,
#          80000., 157000., 128000., 110000., 240000.,  77000.,  53000.,
#         114000., 248000.,  69000.,  95000., 151000., 384000.,  37000.,
#         245000.,  42000.,  71000.,  96000., 162000.,  33000.,  89000.,
#         228000., 174000., 163000., 125000.,  46000.,  23000., 150000.,
#          15000.,  62000.,  32000.,  75000.,  73000.,  47000.,  85000.,
#          64000.,  90000.,  45000., 232000.,  74000.,  84000., 186000.,
#         154000., 164000.,  28000.,  91000., 212000.,  57000., 138000.,
#          86000., 308000.,  59000.,  92000.,   2000., 140000.,  83000.,
#         176000., 189000., 194000., 237000., 208000., 127000.,  55000.,
#         254000.,  81000., 109000.]),
#  'searnings_03': array([    nan,      0., 100000.,  20000.,  30000.,  10000.,  70000.,
#         150000.,  60000.,  80000., 200000.,  50000., 120000., 300000.,
#         140000.,  40000., 360000., 570000., 160000., 190000.,  90000.,
#         220000., 110000., 170000., 260000., 270000., 240000., 130000.,
#         960000., 210000.]),
#  'hincome_03': array([     nan,       0.,   70000.,   20000.,  130000.,   30000.,
#          100000.,  460000.,   10000.,  160000.,   40000.,   50000.,
#          170000.,  110000.,  250000.,  140000.,   90000.,   60000.,
#         2550000.,  580000.,   80000.,  690000.,  330000.,  230000.,
#          120000., 2150000.,  310000.,  320000.,  900000.,  -10000.,
#          150000.,  200000.,  300000.,  890000.,  990000.,  820000.,
#          180000.,  260000.,  370000.,  410000.,  400000., 1200000.,
#          270000.,  280000.,  570000.,  190000.,  210000.,  350000.,
#          220000.,  760000.,  360000., 1310000.,  420000.,  380000.,
#          700000.,  240000.,  490000.,  520000.,  480000.,  -30000.,
#         1470000.,  440000.,  870000.,  600000.,  390000.,  620000.,
#          430000.,  540000., 1040000.,  710000.,  450000., 1050000.,
#          470000.,  530000.,  660000.,  840000.,  670000., 1210000.]),
#  'hinc_business_03': array([     nan,       0.,   70000.,  120000.,  460000.,  160000.,
#           40000.,   30000.,   20000.,  240000.,  100000.,   10000.,
#           80000.,  580000.,  230000.,   50000., 1320000.,  150000.,
#          130000.,  280000.,  200000.,  890000.,  970000.,  800000.,
#          400000.,   90000.,   60000.,  110000.,  330000.,  220000.,
#         1270000.,  140000.,  180000.,  170000.,  690000.,  360000.,
#          350000.,  380000.,  990000.,  870000.,  480000.,  600000.,
#          750000.,  560000.,  440000.,  430000.,  570000.,  300000.,
#          540000.,  710000.,  190000.,  620000.,  250000., 1020000.,
#          530000.,  650000.,  660000., 1200000.]),
#  'hinc_rent_03': array([     nan,       0.,   20000.,   60000.,   10000.,  820000.,
#          300000.,  900000.,  -30000.,  -10000.,   40000.,  220000.,
#          -40000.,   80000.,   30000.,  420000.,   50000.,  -50000.,
#          130000.,  100000.,  140000.,  -20000.,  120000., -100000.,
#          170000.,  160000.,  110000.,  200000.]),
#  'hinc_assets_03': array([   nan,     0.,  8000., 18000.,  1000.,  2000., 14000., 10000.,
#         11000.,  5000., 24000., 12000., 22000.,  4000.,  3000., 15000.,
#         40000.,  9000., 31000., 36000., 13000.,  6000., 26000., 16000.,
#         27000., 25000.,  7000.]),
#  'hinc_cap_03': array([     nan,       0.,   70000.,  120000.,  460000.,  160000.,
#           40000.,   30000.,   20000.,  240000.,   60000.,  100000.,
#           10000.,   80000.,  580000.,  230000.,   50000., 2150000.,
#          300000.,  900000.,  -30000.,  150000.,  130000.,  280000.,
#          200000.,  890000.,  970000.,  800000.,  220000.,  400000.,
#           90000.,  110000.,  330000., 1270000.,  420000.,  140000.,
#          380000.,  180000.,  170000.,  690000.,  360000.,  -20000.,
#          350000.,  -10000.,  990000.,  870000.,  480000.,  600000.,
#          750000.,  560000.,  440000.,  430000.,  570000.,  540000.,
#          710000.,  210000.,  620000.,  250000., 1020000.,  530000.,
#          650000.,  660000., 1200000.]),
#  'rinc_pension_03': array([    nan,      0.,  16000.,  72000.,  34000., 120000.,  10000.,
#          14000.,  55000.,  17000.,  24000.,  13000.,  18000.,  36000.,
#          22000.,  19000.,  82000.,  20000.,  23000.,  98000.,   8000.,
#          96000., 168000., 108000.,  83000.,  12000.,  48000., 180000.,
#          71000.,   7000.,  76000., 264000.,  30000.,  84000.,  42000.,
#          51000.,  11000., 144000.,  54000., 360000.,  33000.,  26000.,
#          41000.,  44000.,   4000.,  60000.,   2000.,   3000.,  35000.,
#         137000.,  46000.,  15000., 156000.,  61000.,  49000.,  28000.,
#         158000.,  40000.,   6000.,  31000.,  25000.,  64000.,  58000.,
#          32000.,  52000.,  70000.,  38000.,  90000., 480000.,  66000.,
#          29000.,  85000., 149000.]),
#  'sinc_pension_03': array([    nan,      0.,  38000.,  14000.,  25000.,  16000.,  60000.,
#          22000.,  96000.,  17000.,  35000.,  18000.,  30000.,  10000.,
#           2000.,  84000., 216000.,  28000.,  20000.,  24000.,  12000.,
#          48000., 180000.,  41000.,  54000.,  13000.,  11000., 144000.,
#          72000., 120000.,  81000., 130000.,  23000.,  76000., 108000.,
#          42000.,  49000.,   5000.,  29000.,  97000.,  36000., 114000.,
#          19000., 132000.,  58000.,  44000., 127000.,  70000.,  31000.,
#         168000.,  15000., 156000., 204000.,  32000., 115000., 109000.,
#          66000., 185000.,   8000., 360000.,  21000., 192000.,  98000.,
#          61000.,  52000.,  34000.]),
#  'rjob_hrswk_12': array([ 66.,  72.,  nan,  60.,  35.,  24.,  42.,  19.,  36.,  48.,  45.,
#          39.,  56.,  55.,   5.,  84.,  30.,   9.,  52.,  28.,   0.,  14.,
#          25.,  54.,  40.,  49.,  10.,  16.,  20.,  98.,  44.,  58.,   4.,
#          93.,  21.,  61.,  12.,   8.,  70.,  46.,  15.,  96.,  91.,   3.,
#          50.,  18.,   6.,  65.,  77.,  67.,  26.,  38.,  59.,  47.,  51.,
#          64.,  43.,  68.,  29.,  34.,  33.,  53.,  37.,  31., 111.,  41.,
#          94.,  32.,  23.,  27.,  22.,  73.,  69.,  11.,  97., 109.,  90.,
#          71.,  63.,  57.,  87.,  82.,  83., 105.,  80., 168.,  85.,  62.,
#          81.,  75.,  78.,   7.,  86., 119.]),
#  'rjob_end_12': array([  nan, 2007., 1962., 2010., 2012., 1995., 1987., 2005., 2003.,
#         2008., 1996., 1950., 2004., 1994., 1949., 2000., 1992., 1989.,
#         1963., 2001., 2011., 1952., 1984., 1980., 1988., 1964., 2006.,
#         1960., 1946., 2009., 1973., 1990., 1959., 1961., 1972., 1970.,
#         1971., 1979., 1982., 1977., 2002., 1958., 1998., 1978., 1974.,
#         1991., 1945., 1968., 1954., 1997., 1948., 1967., 1993., 1983.,
#         1951., 1935., 1986., 1965., 1947., 1955., 1981., 1969., 1975.,
#         1944., 1976., 1956., 1999., 1966., 1943., 1957., 1941., 1985.]),
#  'rearnings_12': array([      0.,   70000.,   10000.,   30000.,   50000.,   20000.,
#           60000.,  100000.,  290000.,   80000.,      nan,  150000.,
#           40000.,  190000.,  110000.,  120000., 1030000.,   90000.,
#          460000.,  200000.,  360000.,  140000.,  430000.,  300000.,
#          180000.,  130000.,  810000.,  170000., 1160000.,  250000.,
#          610000.,  580000.,  240000.,  740000.,  270000.,  220000.,
#          280000.,  720000.,  420000.,  690000.,  680000.,  160000.,
#          260000.,  210000.,  310000.]),
#  'searnings_12': array([      0.,      nan,  160000.,   60000.,   50000.,  100000.,
#         1370000.,   40000.,   70000.,   30000.,   20000.,   10000.,
#          140000.,   80000.,  110000.,  210000.,  240000.,  130000.,
#           90000.,  300000.,  180000.,  250000.,  120000.,  790000.,
#          190000.,  450000.,  170000.,  350000.,  320000.,  530000.,
#          280000.,  220000.,  150000.,  610000.,  430000.,  310000.,
#         1030000.,  680000.]),
#  'hincome_12': array([ 1.400e+05,  7.000e+04,  0.000e+00,  1.000e+04,  3.000e+04,
#          8.000e+04, -3.000e+04,  1.600e+05,  6.000e+04,  2.500e+05,
#          1.100e+05,  5.000e+04,  1.700e+05,  2.000e+04,  4.000e+04,
#          1.000e+05,  9.000e+04,  1.200e+05,  1.300e+05, -1.000e+04,
#          2.900e+05,        nan,  1.520e+06,  1.800e+05,  5.000e+05,
#          3.600e+05,  9.100e+05,  2.700e+05,  2.800e+05,  1.500e+05,
#          1.900e+05,  1.060e+06,  2.400e+05,  2.000e+05,  3.300e+05,
#          1.030e+06,  2.200e+05,  2.300e+05,  6.200e+05,  4.700e+05,
#          3.800e+05,  2.600e+05,  1.230e+06,  2.100e+05,  6.100e+05,
#          1.110e+06,  4.900e+05,  8.700e+05,  1.080e+06,  7.200e+05,
#          4.300e+05,  3.400e+05,  3.000e+05,  1.810e+06,  6.000e+05,
#         -1.900e+05,  1.200e+06,  2.050e+06,  3.700e+05,  9.800e+05,
#          3.602e+07,  7.900e+05,  1.050e+06,  2.400e+06,  4.800e+05,
#          1.000e+06,  6.900e+05,  3.200e+05,  1.170e+06,  4.500e+05,
#          1.590e+06,  6.500e+05,  5.500e+05,  4.200e+05,  3.500e+05,
#          6.400e+05,  1.650e+06,  3.100e+05,  1.160e+06,  4.000e+05,
#          5.530e+06,  5.800e+05, -1.500e+05,  3.900e+05,  5.300e+05,
#          2.290e+06,  1.420e+06,  6.020e+06,  1.480e+06, -9.000e+04,
#          6.300e+05,  1.210e+06,  7.400e+05,  1.070e+06, -2.000e+04,
#          4.300e+06,  5.900e+05,  9.600e+05,  6.800e+05,  1.140e+06,
#          8.600e+05, -5.000e+04,  5.100e+05,  8.300e+05,  5.700e+05,
#          6.600e+05,  1.440e+06,  2.270e+06]),
#  'hinc_business_12': array([1.00e+04, 0.00e+00, 2.40e+05, 1.10e+05, 4.00e+04,      nan,
#         3.00e+04, 1.80e+05, 4.90e+05, 3.60e+05, 9.10e+05, 2.00e+04,
#         1.00e+05, 6.00e+04, 7.00e+04, 1.05e+06, 8.40e+05, 3.30e+05,
#         4.10e+05, 1.50e+05, 1.90e+05, 8.00e+04, 4.30e+05, 1.07e+06,
#         7.20e+05, 5.00e+04, 1.20e+05, 1.80e+06, 1.60e+05, 2.05e+06,
#         3.60e+07, 9.80e+05, 4.40e+05, 1.38e+06, 1.59e+06, 6.00e+05,
#         1.43e+06, 1.40e+05, 3.70e+05, 1.20e+06, 2.29e+06, 7.90e+05,
#         1.37e+06, 1.02e+06, 3.50e+05, 1.27e+06, 9.60e+05, 2.00e+05,
#         5.80e+05, 1.52e+06, 5.90e+05, 1.70e+05, 4.80e+05, 1.14e+06,
#         2.30e+05, 9.00e+04, 6.10e+05, 3.00e+05, 1.65e+06, 1.44e+06,
#         2.24e+06]),
#  'hinc_rent_12': array([      0.,  -60000.,  -10000.,   90000.,      nan,   10000.,
#           20000.,   60000.,  -40000.,  340000.,   40000.,  840000.,
#         -360000.,   50000.,  -20000., -210000., 1200000., -160000.,
#         -140000.,  100000.,  540000., -170000.,   80000.,   30000.,
#         -120000.,  400000.,  -50000.,  110000., -180000.,  -80000.,
#          170000.,   70000.,  -30000.]),
#  'hinc_assets_12': array([     0.,     nan,   8000., 232000.,  22000.,   6000.,   1000.,
#          91000.,  19000.,  89000.,  31000., 129000.,  93000.,  15000.,
#         105000.,  72000.,  12000.,  36000.,  41000.,  11000., 103000.,
#          16000., 180000.,   7000.,   2000.,  20000.,  17000.,   5000.,
#          73000.,  98000.,  74000.,  24000.,  42000.,  60000., 360000.,
#          14000.,   4000.]),
#  'hinc_cap_12': array([ 1.00e+04,  0.00e+00, -6.00e+04,  2.40e+05,  1.10e+05, -1.00e+04,
#          4.00e+04,  9.00e+04,       nan,  3.00e+04,  1.80e+05,  4.90e+05,
#          3.60e+05,  9.10e+05,  2.30e+05,  2.00e+04,  1.00e+05,  6.00e+04,
#          7.00e+04,  1.05e+06,  8.40e+05,  3.30e+05,  4.10e+05,  1.50e+05,
#          1.90e+05, -4.00e+04,  8.00e+04,  3.40e+05,  4.30e+05,  1.07e+06,
#          1.30e+05,  5.00e+04,  1.20e+05,  1.80e+06,  1.60e+05, -2.00e+04,
#         -2.10e+05,  1.20e+06,  2.05e+06,  3.60e+07,  9.80e+05,  4.40e+05,
#          1.22e+06,  1.59e+06,  6.00e+05,  1.43e+06, -1.40e+05,  1.40e+05,
#          5.80e+05, -1.70e+05,  3.70e+05,  2.29e+06,  7.90e+05,  1.37e+06,
#          1.02e+06,  3.50e+05,  1.46e+06,  9.60e+05, -1.20e+05,  7.20e+05,
#         -5.00e+04,  1.52e+06,  5.90e+05,  1.70e+05,  2.70e+05,  4.80e+05,
#          1.14e+06, -3.00e+04,  6.10e+05,  3.00e+05,  1.65e+06,  1.44e+06,
#          2.24e+06]),
#  'rinc_pension_12': array([     0.,  30000., 170000.,  20000.,  10000.,  70000.,     nan,
#          60000.,  50000.,  80000.,  40000., 120000., 100000., 200000.,
#         130000., 150000., 240000., 110000., 720000., 220000., 260000.,
#         600000., 960000., 140000., 480000., 190000., 430000., 360000.,
#          90000., 250000., 230000., 180000., 160000., 310000., 320000.,
#         290000., 300000.]),
#  'sinc_pension_12': array([      0.,      nan,   30000.,   40000.,   10000.,  120000.,
#           20000.,   80000.,  240000.,  200000.,  100000.,   70000.,
#           60000.,   50000.,  480000.,  190000.,  140000.,  160000.,
#          110000.,  170000.,  340000.,  150000.,  130000.,  180000.,
#         1200000.,   90000.,  220000.,  360000.,  260000.,  280000.,
#          600000.,  230000.]),
#  'a16a_12': array([  nan, 1978., 1987., 1965., 1960., 1970., 1951., 2002., 1975.,
#         1993., 2012., 1962., 1976., 2010., 2005., 1957., 1945., 1985.,
#         1942., 1964., 1958., 1969.]),
#  'a21_12': array([nan,  1., 52.,  3., 40., 15.,  7.,  2., 30.,  4.,  5.,  6., 36.,
#         10., 27., 34.])}

# %%
# Identify columns with missing values in train_features and calculate the percentage of missing values for each
missing_values_features = train_features.isnull().mean() * 100
columns_with_missing_values = missing_values_features[missing_values_features > 0]

# Extract the columns with missing values for inspection
missing_values_data = train_features[columns_with_missing_values.index]

# Display the percentage of missing values in each column and the unique values for each
missing_values_info = {col: {"missing_percentage": columns_with_missing_values[col],
                             "unique_values": missing_values_data[col].unique()}
                       for col in columns_with_missing_values.index}

missing_values_info
# Out:
# {'age_03': {'missing_percentage': 31.62393162393162,
#   'unique_values': array([nan, '1. 50–59', '3. 70–79', '2. 60–69', '0. 49 or younger',
#          '4. 80+'], dtype=object)},
#  'urban_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan, '1. 100,000+', '0. <100,000'], dtype=object)},
#  'married_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan, '3. Widowed', '1. Married or in civil union', '4. Single',
#          '2. Separated or divorced'], dtype=object)},
#  'n_mar_03': {'missing_percentage': 32.17338217338217,
#   'unique_values': array([nan,  1.,  2.,  3.,  0.,  4.,  5.])},
#  'edu_gru_03': {'missing_percentage': 31.868131868131865,
#   'unique_values': array([nan, '3. 7–9 years', '1. 1–5 years', '0. No education',
#          '2. 6 years', '4. 10+ years'], dtype=object)},
#  'n_living_child_03': {'missing_percentage': 31.929181929181926,
#   'unique_values': array([nan, '1. 1 or 2', '3. 5 or 6', '0. No children', '2. 3 or 4',
#          '4. 7+'], dtype=object)},
#  'migration_03': {'missing_percentage': 31.59340659340659,
#   'unique_values': array([nan,  0.,  1.])},
#  'glob_hlth_03': {'missing_percentage': 35.775335775335776,
#   'unique_values': array([nan, '4. Fair', '5. Poor', '3. Good', '1. Excellent',
#          '2. Very good'], dtype=object)},
#  'adl_dress_03': {'missing_percentage': 35.74481074481074,
#   'unique_values': array([nan,  0.,  1.])},
#  'adl_walk_03': {'missing_percentage': 31.776556776556774,
#   'unique_values': array([nan,  0.,  1.])},
#  'adl_bath_03': {'missing_percentage': 31.776556776556774,
#   'unique_values': array([nan,  0.,  1.])},
#  'adl_eat_03': {'missing_percentage': 31.807081807081804,
#   'unique_values': array([nan,  0.,  1.])},
#  'adl_bed_03': {'missing_percentage': 31.776556776556774,
#   'unique_values': array([nan,  0.,  1.])},
#  'adl_toilet_03': {'missing_percentage': 31.776556776556774,
#   'unique_values': array([nan,  0.,  1.])},
#  'n_adl_03': {'missing_percentage': 31.807081807081804,
#   'unique_values': array([nan,  0.,  1.,  2.,  3.,  5.,  4.])},
#  'iadl_money_03': {'missing_percentage': 35.74481074481074,
#   'unique_values': array([nan,  0.,  1.])},
#  'iadl_meds_03': {'missing_percentage': 35.74481074481074,
#   'unique_values': array([nan,  0.,  1.])},
#  'iadl_shop_03': {'missing_percentage': 35.74481074481074,
#   'unique_values': array([nan,  0.,  1.])},
#  'iadl_meals_03': {'missing_percentage': 35.74481074481074,
#   'unique_values': array([nan,  0.,  1.])},
#  'n_iadl_03': {'missing_percentage': 35.74481074481074,
#   'unique_values': array([nan,  0.,  1.,  3.,  2.,  4.])},
#  'depressed_03': {'missing_percentage': 35.866910866910864,
#   'unique_values': array([nan,  1.,  0.])},
#  'hard_03': {'missing_percentage': 35.775335775335776,
#   'unique_values': array([nan,  0.,  1.])},
#  'restless_03': {'missing_percentage': 35.775335775335776,
#   'unique_values': array([nan,  1.,  0.])},
#  'happy_03': {'missing_percentage': 35.95848595848596,
#   'unique_values': array([nan,  1.,  0.])},
#  'lonely_03': {'missing_percentage': 35.775335775335776,
#   'unique_values': array([nan,  1.,  0.])},
#  'enjoy_03': {'missing_percentage': 35.927960927960925,
#   'unique_values': array([nan,  1.,  0.])},
#  'sad_03': {'missing_percentage': 35.74481074481074,
#   'unique_values': array([nan,  1.,  0.])},
#  'tired_03': {'missing_percentage': 35.74481074481074,
#   'unique_values': array([nan,  1.,  0.])},
#  'energetic_03': {'missing_percentage': 35.989010989010985,
#   'unique_values': array([nan,  0.,  1.])},
#  'n_depr_03': {'missing_percentage': 35.8974358974359,
#   'unique_values': array([nan,  6.,  7.,  3.,  5.,  9.,  4.,  2.,  1.,  0.,  8.])},
#  'cesd_depressed_03': {'missing_percentage': 35.8974358974359,
#   'unique_values': array([nan,  1.,  0.])},
#  'hypertension_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'diabetes_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  1.,  0.])},
#  'resp_ill_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'arthritis_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'hrt_attack_03': {'missing_percentage': 31.59340659340659,
#   'unique_values': array([nan,  0.,  1.])},
#  'stroke_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'cancer_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'n_illnesses_03': {'missing_percentage': 31.59340659340659,
#   'unique_values': array([nan,  1.,  0.,  3.,  2.,  4.,  5.])},
#  'bmi_03': {'missing_percentage': 51.92307692307693,
#   'unique_values': array([nan, '3. Overweight', '4. Obese', '1. Underweight',
#          '2. Normal weight', '5. Morbidly obese'], dtype=object)},
#  'exer_3xwk_03': {'missing_percentage': 35.74481074481074,
#   'unique_values': array([nan,  1.,  0.])},
#  'alcohol_03': {'missing_percentage': 31.59340659340659,
#   'unique_values': array([nan,  0.,  1.])},
#  'tobacco_03': {'missing_percentage': 31.59340659340659,
#   'unique_values': array([nan,  0.,  1.])},
#  'test_chol_03': {'missing_percentage': 35.95848595848596,
#   'unique_values': array([nan,  1.,  0.])},
#  'test_tuber_03': {'missing_percentage': 36.08058608058608,
#   'unique_values': array([nan,  0.,  1.])},
#  'test_diab_03': {'missing_percentage': 35.8058608058608,
#   'unique_values': array([nan,  1.,  0.])},
#  'test_pres_03': {'missing_percentage': 35.8058608058608,
#   'unique_values': array([nan,  1.,  0.])},
#  'hosp_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'visit_med_03': {'missing_percentage': 31.684981684981683,
#   'unique_values': array([nan,  1.,  0.])},
#  'out_proc_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'visit_dental_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'imss_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'issste_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'pem_def_mar_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'insur_private_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'insur_other_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'insured_03': {'missing_percentage': 31.56288156288156,
#   'unique_values': array([nan,  0.,  1.])},
#  'decis_famil_03': {'missing_percentage': 52.533577533577535,
#   'unique_values': array([nan, '2. Approximately equal weight', '1. Respondent', '3. Spouse'],
#         dtype=object)},
#  'decis_personal_03': {'missing_percentage': 35.95848595848596,
#   'unique_values': array([nan,  1.,  2.,  3.])},
#  'employment_03': {'missing_percentage': 31.62393162393162,
#   'unique_values': array([nan, '3. Dedicated to household chores', '1. Currently Working',
#          '2. Currently looking for work',
#          '4. Retired, incapacitated, or does not work'], dtype=object)},
#  'age_12': {'missing_percentage': 2.7472527472527473,
#   'unique_values': array(['2. 60–69', '1. 50–59', '4. 80+', '3. 70–79', nan,
#          '0. 49 or younger'], dtype=object)},
#  'urban_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array(['0. <100,000', '1. 100,000+', nan], dtype=object)},
#  'married_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array(['1. Married or in civil union', '3. Widowed',
#          '2. Separated or divorced', nan, '4. Single'], dtype=object)},
#  'n_mar_12': {'missing_percentage': 3.5409035409035408,
#   'unique_values': array([ 1.,  2.,  3.,  4., nan,  0.,  5.,  7.])},
#  'edu_gru_12': {'missing_percentage': 3.0525030525030523,
#   'unique_values': array(['0. No education', '3. 7–9 years', '1. 1–5 years', '2. 6 years',
#          '4. 10+ years', nan], dtype=object)},
#  'n_living_child_12': {'missing_percentage': 3.357753357753358,
#   'unique_values': array(['1. 1 or 2', '3. 5 or 6', '0. No children', '2. 3 or 4', '4. 7+',
#          nan], dtype=object)},
#  'migration_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([ 0.,  1., nan])},
#  'glob_hlth_12': {'missing_percentage': 6.593406593406594,
#   'unique_values': array(['4. Fair', '3. Good', '2. Very good', '5. Poor', nan,
#          '1. Excellent'], dtype=object)},
#  'adl_dress_12': {'missing_percentage': 6.593406593406594,
#   'unique_values': array([ 0.,  1., nan])},
#  'adl_walk_12': {'missing_percentage': 3.0525030525030523,
#   'unique_values': array([nan,  0.,  1.])},
#  'adl_bath_12': {'missing_percentage': 3.357753357753358,
#   'unique_values': array([nan,  0.,  1.])},
#  'adl_eat_12': {'missing_percentage': 3.1135531135531136,
#   'unique_values': array([nan,  0.,  1.])},
#  'adl_bed_12': {'missing_percentage': 3.083028083028083,
#   'unique_values': array([nan,  0.,  1.])},
#  'adl_toilet_12': {'missing_percentage': 3.083028083028083,
#   'unique_values': array([nan,  0.,  1.])},
#  'n_adl_12': {'missing_percentage': 3.418803418803419,
#   'unique_values': array([nan,  0.,  1.,  3.,  2.,  5.,  4.])},
#  'iadl_money_12': {'missing_percentage': 6.623931623931624,
#   'unique_values': array([ 0., nan,  1.])},
#  'iadl_meds_12': {'missing_percentage': 6.623931623931624,
#   'unique_values': array([ 0., nan,  1.])},
#  'iadl_shop_12': {'missing_percentage': 6.623931623931624,
#   'unique_values': array([ 0.,  1., nan])},
#  'iadl_meals_12': {'missing_percentage': 6.623931623931624,
#   'unique_values': array([ 0., nan,  1.])},
#  'n_iadl_12': {'missing_percentage': 6.654456654456655,
#   'unique_values': array([ 0.,  1., nan,  2.,  3.,  4.])},
#  'depressed_12': {'missing_percentage': 6.7765567765567765,
#   'unique_values': array([ 0.,  1., nan])},
#  'hard_12': {'missing_percentage': 6.654456654456655,
#   'unique_values': array([ 0.,  1., nan])},
#  'restless_12': {'missing_percentage': 6.684981684981685,
#   'unique_values': array([ 0.,  1., nan])},
#  'happy_12': {'missing_percentage': 6.807081807081807,
#   'unique_values': array([ 1.,  0., nan])},
#  'lonely_12': {'missing_percentage': 6.684981684981685,
#   'unique_values': array([ 0.,  1., nan])},
#  'enjoy_12': {'missing_percentage': 6.746031746031746,
#   'unique_values': array([ 1.,  0., nan])},
#  'sad_12': {'missing_percentage': 6.684981684981685,
#   'unique_values': array([ 0.,  1., nan])},
#  'tired_12': {'missing_percentage': 6.623931623931624,
#   'unique_values': array([ 0.,  1., nan])},
#  'energetic_12': {'missing_percentage': 6.654456654456655,
#   'unique_values': array([ 1.,  0., nan])},
#  'n_depr_12': {'missing_percentage': 7.234432234432235,
#   'unique_values': array([ 0.,  4.,  8.,  5.,  3.,  7.,  6.,  1.,  2., nan,  9.])},
#  'cesd_depressed_12': {'missing_percentage': 7.234432234432235,
#   'unique_values': array([ 0.,  1., nan])},
#  'hypertension_12': {'missing_percentage': 2.9914529914529915,
#   'unique_values': array([ 1.,  0., nan])},
#  'diabetes_12': {'missing_percentage': 2.9914529914529915,
#   'unique_values': array([ 0.,  1., nan])},
#  'resp_ill_12': {'missing_percentage': 2.8693528693528694,
#   'unique_values': array([ 0.,  1., nan])},
#  'arthritis_12': {'missing_percentage': 2.9914529914529915,
#   'unique_values': array([ 0.,  1., nan])},
#  'hrt_attack_12': {'missing_percentage': 2.8998778998779,
#   'unique_values': array([ 0.,  1., nan])},
#  'stroke_12': {'missing_percentage': 2.838827838827839,
#   'unique_values': array([ 0., nan,  1.])},
#  'cancer_12': {'missing_percentage': 2.9914529914529915,
#   'unique_values': array([ 0.,  1., nan])},
#  'n_illnesses_12': {'missing_percentage': 3.6019536019536016,
#   'unique_values': array([ 1.,  0.,  3.,  2., nan,  4.,  5.])},
#  'bmi_12': {'missing_percentage': 13.36996336996337,
#   'unique_values': array(['3. Overweight', '4. Obese', '2. Normal weight', nan,
#          '1. Underweight', '5. Morbidly obese'], dtype=object)},
#  'exer_3xwk_12': {'missing_percentage': 6.593406593406594,
#   'unique_values': array([ 1.,  0., nan])},
#  'alcohol_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([ 0.,  1., nan])},
#  'tobacco_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([ 0.,  1., nan])},
#  'test_chol_12': {'missing_percentage': 6.868131868131869,
#   'unique_values': array([ 0.,  1., nan])},
#  'test_tuber_12': {'missing_percentage': 7.753357753357753,
#   'unique_values': array([ 0., nan,  1.])},
#  'test_diab_12': {'missing_percentage': 6.684981684981685,
#   'unique_values': array([ 1.,  0., nan])},
#  'test_pres_12': {'missing_percentage': 6.684981684981685,
#   'unique_values': array([ 1.,  0., nan])},
#  'hosp_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([ 0.,  1., nan])},
#  'visit_med_12': {'missing_percentage': 2.8998778998779,
#   'unique_values': array([ 1.,  0., nan])},
#  'out_proc_12': {'missing_percentage': 2.7472527472527473,
#   'unique_values': array([ 0.,  1., nan])},
#  'visit_dental_12': {'missing_percentage': 2.8998778998779,
#   'unique_values': array([ 0.,  1., nan])},
#  'imss_12': {'missing_percentage': 2.8083028083028085,
#   'unique_values': array([ 0.,  1., nan])},
#  'issste_12': {'missing_percentage': 2.7777777777777777,
#   'unique_values': array([ 0.,  1., nan])},
#  'pem_def_mar_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([ 0., nan,  1.])},
#  'insur_private_12': {'missing_percentage': 2.7777777777777777,
#   'unique_values': array([ 0.,  1., nan])},
#  'insur_other_12': {'missing_percentage': 2.838827838827839,
#   'unique_values': array([ 1.,  0., nan])},
#  'insured_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([ 1.,  0., nan])},
#  'decis_famil_12': {'missing_percentage': 37.423687423687426,
#   'unique_values': array(['2. Approximately equal weight', '3. Spouse', nan, '1. Respondent'],
#         dtype=object)},
#  'decis_personal_12': {'missing_percentage': 6.868131868131869,
#   'unique_values': array(['1. A lot', '2. A little', nan, '3. None'], dtype=object)},
#  'employment_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array(['1. Currently Working', '2. Currently looking for work',
#          '3. Dedicated to household chores',
#          '4. Retired, incapacitated, or does not work', nan], dtype=object)},
#  'vax_flu_12': {'missing_percentage': 6.807081807081807,
#   'unique_values': array([ 0.,  1., nan])},
#  'vax_pneu_12': {'missing_percentage': 8.882783882783883,
#   'unique_values': array([ 0.,  1., nan])},
#  'seg_pop_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([ 1.,  0., nan])},
#  'care_adult_12': {'missing_percentage': 6.593406593406594,
#   'unique_values': array([ 0.,  1., nan])},
#  'care_child_12': {'missing_percentage': 6.623931623931624,
#   'unique_values': array([ 0.,  1., nan])},
#  'volunteer_12': {'missing_percentage': 6.684981684981685,
#   'unique_values': array([ 0.,  1., nan])},
#  'attends_class_12': {'missing_percentage': 6.623931623931624,
#   'unique_values': array([ 0.,  1., nan])},
#  'attends_club_12': {'missing_percentage': 6.593406593406594,
#   'unique_values': array([ 0.,  1., nan])},
#  'reads_12': {'missing_percentage': 6.868131868131869,
#   'unique_values': array([ 1.,  0., nan])},
#  'games_12': {'missing_percentage': 6.684981684981685,
#   'unique_values': array([ 0.,  1., nan])},
#  'table_games_12': {'missing_percentage': 6.684981684981685,
#   'unique_values': array([ 0.,  1., nan])},
#  'comms_tel_comp_12': {'missing_percentage': 6.654456654456655,
#   'unique_values': array([ 0.,  1., nan])},
#  'act_mant_12': {'missing_percentage': 6.593406593406594,
#   'unique_values': array([ 1.,  0., nan])},
#  'tv_12': {'missing_percentage': 6.593406593406594,
#   'unique_values': array([ 1.,  0., nan])},
#  'sewing_12': {'missing_percentage': 6.593406593406594,
#   'unique_values': array([ 0.,  1., nan])},
#  'satis_ideal_12': {'missing_percentage': 8.455433455433456,
#   'unique_values': array(['3. Disagrees', '1. Agrees', '2. Neither agrees nor disagrees',
#          nan], dtype=object)},
#  'satis_excel_12': {'missing_percentage': 7.295482295482296,
#   'unique_values': array(['3. Disagrees', '2. Neither agrees nor disagrees', '1. Agrees',
#          nan], dtype=object)},
#  'satis_fine_12': {'missing_percentage': 6.807081807081807,
#   'unique_values': array(['1. Agrees', '3. Disagrees', '2. Neither agrees nor disagrees',
#          nan], dtype=object)},
#  'cosas_imp_12': {'missing_percentage': 6.95970695970696,
#   'unique_values': array(['1. Agrees', '2. Neither agrees nor disagrees', '3. Disagrees',
#          nan], dtype=object)},
#  'wouldnt_change_12': {'missing_percentage': 7.57020757020757,
#   'unique_values': array(['3. Disagrees', '1. Agrees', '2. Neither agrees nor disagrees',
#          nan], dtype=object)},
#  'memory_12': {'missing_percentage': 7.478632478632479,
#   'unique_values': array(['2. Very good', '4. Fair', '3. Good', nan, '5. Poor',
#          '1. Excellent'], dtype=object)},
#  'rameduc_m': {'missing_percentage': 12.637362637362637,
#   'unique_values': array(['1.None', '2.Some primary', '3.Primary', nan,
#          '4.More than primary'], dtype=object)},
#  'rafeduc_m': {'missing_percentage': 15.323565323565324,
#   'unique_values': array(['1.None', '2.Some primary', '4.More than primary', '3.Primary',
#          nan], dtype=object)},
#  'sgender_03': {'missing_percentage': 47.25274725274725,
#   'unique_values': array([nan, '2.Woman', '1.Man'], dtype=object)},
#  'rjob_hrswk_03': {'missing_percentage': 65.10989010989012,
#   'unique_values': array([nan, 30., 48., 35.,  5., 72., 36., 42., 63., 45., 12.,  6., 40.,
#          55., 18., 57., 15., 60., 84., 39., 16., 21., 70., 56., 50., 20.,
#          66., 90., 49., 44., 47.,  9., 25., 99.,  4., 28., 87., 64., 77.,
#          52., 24., 54., 13., 46., 26., 14.,  7., 10., 94., 23., 81.,  3.,
#          68., 58., 71., 73., 76., 32., 38., 27., 91., 22.,  8., 74., 79.,
#          31., 80., 67., 62., 82., 65., 59., 29., 88., 85.,  1., 43., 78.,
#          34., 17., 53., 33., 19.])},
#  'rjlocc_m_03': {'missing_percentage': 90.50671550671551,
#   'unique_values': array([nan, '6.Workers in Agriculture, Livestock, Forestry, and Fishing',
#          '18.Safety and Security Personnel',
#          '15.Traveling Salespeople and Traveling Salespeople of Services',
#          '8.Artisans and Workers in Production, Repair, Maintenance',
#          '14.Merchants and Sales Representatives', '1.Professionals',
#          '17.Domestic Workers',
#          '9.Operators of Fixed Machinery and Equipment for Ind. Production',
#          '16.Workers in the Service Industry', '19.Other Workers',
#          '11.Drivers and Asst Drivers of Mobile Machinery and Transport Vehicles',
#          '10.Asst/Laborers etc in Ind. Production, Repair, Maintenance',
#          '13.Administrative Support Staff',
#          '4.Workers in Art, Shows, and Sports',
#          '5.Officials and Directors Public, Private, and Social Sectors',
#          '3.Educators', '2.Technicians',
#          '12.Department Heads/Coordinators/Supervisors in Admin and Service Activities'],
#         dtype=object)},
#  'rjob_end_03': {'missing_percentage': 89.65201465201466,
#   'unique_values': array([  nan, 2003., 1973., 1967., 1993., 2001., 2002., 1953., 1991.,
#          1985., 2000., 1978., 1997., 1999., 1971., 1969., 1968., 1995.,
#          1996., 1998., 1958., 1986., 1983., 1972., 1988., 1981., 1951.,
#          1977., 1979., 1994., 1989., 1965., 1990., 1970., 1963., 1992.,
#          1974., 1941., 1982., 1960., 1980., 1987., 1943., 1976., 1961.,
#          1964., 1975., 1984., 1948.])},
#  'rjobend_reason_03': {'missing_percentage': 89.37728937728939,
#   'unique_values': array([nan, '4.Health reason', '5.Family reason', '1.Retired', '8.Other',
#          '3.Laid off'], dtype=object)},
#  'rearnings_03': {'missing_percentage': 31.654456654456652,
#   'unique_values': array([    nan,      0.,  30000.,  19000.,  48000.,   6000., 108000.,
#           68000.,   8000.,  58000., 260000.,  26000.,  21000.,  52000.,
#           36000.,  12000.,  41000.,   5000.,  24000.,  25000.,  44000.,
#           50000., 130000.,  13000.,   3000.,  11000.,  35000., 112000.,
#           87000.,  39000.,  22000.,  56000.,  14000.,  98000.,  20000.,
#           17000.,  29000.,  38000.,  34000.,  10000.,  79000.,  51000.,
#           31000.,   7000.,  72000.,  54000.,  43000.,  65000.,  78000.,
#           60000.,  40000.,  63000., 100000., 198000.,  94000.,  49000.,
#           88000.,   4000.,  18000., 180000., 149000., 187000.,   9000.,
#           61000.,  76000.,  66000., 156000.,   1000.,  67000., 196000.,
#          216000., 159000., 222000., 102000.,  27000.,  16000.,  70000.,
#           80000., 157000., 128000., 110000., 240000.,  77000.,  53000.,
#          114000., 248000.,  69000.,  95000., 151000., 384000.,  37000.,
#          245000.,  42000.,  71000.,  96000., 162000.,  33000.,  89000.,
#          228000., 174000., 163000., 125000.,  46000.,  23000., 150000.,
#           15000.,  62000.,  32000.,  75000.,  73000.,  47000.,  85000.,
#           64000.,  90000.,  45000., 232000.,  74000.,  84000., 186000.,
#          154000., 164000.,  28000.,  91000., 212000.,  57000., 138000.,
#           86000., 308000.,  59000.,  92000.,   2000., 140000.,  83000.,
#          176000., 189000., 194000., 237000., 208000., 127000.,  55000.,
#          254000.,  81000., 109000.])},
#  'searnings_03': {'missing_percentage': 49.08424908424908,
#   'unique_values': array([    nan,      0., 100000.,  20000.,  30000.,  10000.,  70000.,
#          150000.,  60000.,  80000., 200000.,  50000., 120000., 300000.,
#          140000.,  40000., 360000., 570000., 160000., 190000.,  90000.,
#          220000., 110000., 170000., 260000., 270000., 240000., 130000.,
#          960000., 210000.])},
#  'hincome_03': {'missing_percentage': 32.32600732600733,
#   'unique_values': array([     nan,       0.,   70000.,   20000.,  130000.,   30000.,
#           100000.,  460000.,   10000.,  160000.,   40000.,   50000.,
#           170000.,  110000.,  250000.,  140000.,   90000.,   60000.,
#          2550000.,  580000.,   80000.,  690000.,  330000.,  230000.,
#           120000., 2150000.,  310000.,  320000.,  900000.,  -10000.,
#           150000.,  200000.,  300000.,  890000.,  990000.,  820000.,
#           180000.,  260000.,  370000.,  410000.,  400000., 1200000.,
#           270000.,  280000.,  570000.,  190000.,  210000.,  350000.,
#           220000.,  760000.,  360000., 1310000.,  420000.,  380000.,
#           700000.,  240000.,  490000.,  520000.,  480000.,  -30000.,
#          1470000.,  440000.,  870000.,  600000.,  390000.,  620000.,
#           430000.,  540000., 1040000.,  710000.,  450000., 1050000.,
#           470000.,  530000.,  660000.,  840000.,  670000., 1210000.])},
#  'hinc_business_03': {'missing_percentage': 31.166056166056165,
#   'unique_values': array([     nan,       0.,   70000.,  120000.,  460000.,  160000.,
#            40000.,   30000.,   20000.,  240000.,  100000.,   10000.,
#            80000.,  580000.,  230000.,   50000., 1320000.,  150000.,
#           130000.,  280000.,  200000.,  890000.,  970000.,  800000.,
#           400000.,   90000.,   60000.,  110000.,  330000.,  220000.,
#          1270000.,  140000.,  180000.,  170000.,  690000.,  360000.,
#           350000.,  380000.,  990000.,  870000.,  480000.,  600000.,
#           750000.,  560000.,  440000.,  430000.,  570000.,  300000.,
#           540000.,  710000.,  190000.,  620000.,  250000., 1020000.,
#           530000.,  650000.,  660000., 1200000.])},
#  'hinc_rent_03': {'missing_percentage': 31.166056166056165,
#   'unique_values': array([     nan,       0.,   20000.,   60000.,   10000.,  820000.,
#           300000.,  900000.,  -30000.,  -10000.,   40000.,  220000.,
#           -40000.,   80000.,   30000.,  420000.,   50000.,  -50000.,
#           130000.,  100000.,  140000.,  -20000.,  120000., -100000.,
#           170000.,  160000.,  110000.,  200000.])},
#  'hinc_assets_03': {'missing_percentage': 31.166056166056165,
#   'unique_values': array([   nan,     0.,  8000., 18000.,  1000.,  2000., 14000., 10000.,
#          11000.,  5000., 24000., 12000., 22000.,  4000.,  3000., 15000.,
#          40000.,  9000., 31000., 36000., 13000.,  6000., 26000., 16000.,
#          27000., 25000.,  7000.])},
#  'hinc_cap_03': {'missing_percentage': 31.166056166056165,
#   'unique_values': array([     nan,       0.,   70000.,  120000.,  460000.,  160000.,
#            40000.,   30000.,   20000.,  240000.,   60000.,  100000.,
#            10000.,   80000.,  580000.,  230000.,   50000., 2150000.,
#           300000.,  900000.,  -30000.,  150000.,  130000.,  280000.,
#           200000.,  890000.,  970000.,  800000.,  220000.,  400000.,
#            90000.,  110000.,  330000., 1270000.,  420000.,  140000.,
#           380000.,  180000.,  170000.,  690000.,  360000.,  -20000.,
#           350000.,  -10000.,  990000.,  870000.,  480000.,  600000.,
#           750000.,  560000.,  440000.,  430000.,  570000.,  540000.,
#           710000.,  210000.,  620000.,  250000., 1020000.,  530000.,
#           650000.,  660000., 1200000.])},
#  'rinc_pension_03': {'missing_percentage': 31.654456654456652,
#   'unique_values': array([    nan,      0.,  16000.,  72000.,  34000., 120000.,  10000.,
#           14000.,  55000.,  17000.,  24000.,  13000.,  18000.,  36000.,
#           22000.,  19000.,  82000.,  20000.,  23000.,  98000.,   8000.,
#           96000., 168000., 108000.,  83000.,  12000.,  48000., 180000.,
#           71000.,   7000.,  76000., 264000.,  30000.,  84000.,  42000.,
#           51000.,  11000., 144000.,  54000., 360000.,  33000.,  26000.,
#           41000.,  44000.,   4000.,  60000.,   2000.,   3000.,  35000.,
#          137000.,  46000.,  15000., 156000.,  61000.,  49000.,  28000.,
#          158000.,  40000.,   6000.,  31000.,  25000.,  64000.,  58000.,
#           32000.,  52000.,  70000.,  38000.,  90000., 480000.,  66000.,
#           29000.,  85000., 149000.])},
#  'sinc_pension_03': {'missing_percentage': 49.08424908424908,
#   'unique_values': array([    nan,      0.,  38000.,  14000.,  25000.,  16000.,  60000.,
#           22000.,  96000.,  17000.,  35000.,  18000.,  30000.,  10000.,
#            2000.,  84000., 216000.,  28000.,  20000.,  24000.,  12000.,
#           48000., 180000.,  41000.,  54000.,  13000.,  11000., 144000.,
#           72000., 120000.,  81000., 130000.,  23000.,  76000., 108000.,
#           42000.,  49000.,   5000.,  29000.,  97000.,  36000., 114000.,
#           19000., 132000.,  58000.,  44000., 127000.,  70000.,  31000.,
#          168000.,  15000., 156000., 204000.,  32000., 115000., 109000.,
#           66000., 185000.,   8000., 360000.,  21000., 192000.,  98000.,
#           61000.,  52000.,  34000.])},
#  'rrelgimp_03': {'missing_percentage': 36.63003663003663,
#   'unique_values': array([nan, '1.very important', '2.somewhat important', '3.not important'],
#         dtype=object)},
#  'sgender_12': {'missing_percentage': 36.14163614163614,
#   'unique_values': array(['2.Woman', '1.Man', nan], dtype=object)},
#  'rjob_hrswk_12': {'missing_percentage': 61.53846153846154,
#   'unique_values': array([ 66.,  72.,  nan,  60.,  35.,  24.,  42.,  19.,  36.,  48.,  45.,
#           39.,  56.,  55.,   5.,  84.,  30.,   9.,  52.,  28.,   0.,  14.,
#           25.,  54.,  40.,  49.,  10.,  16.,  20.,  98.,  44.,  58.,   4.,
#           93.,  21.,  61.,  12.,   8.,  70.,  46.,  15.,  96.,  91.,   3.,
#           50.,  18.,   6.,  65.,  77.,  67.,  26.,  38.,  59.,  47.,  51.,
#           64.,  43.,  68.,  29.,  34.,  33.,  53.,  37.,  31., 111.,  41.,
#           94.,  32.,  23.,  27.,  22.,  73.,  69.,  11.,  97., 109.,  90.,
#           71.,  63.,  57.,  87.,  82.,  83., 105.,  80., 168.,  85.,  62.,
#           81.,  75.,  78.,   7.,  86., 119.])},
#  'rjlocc_m_12': {'missing_percentage': 47.924297924297925,
#   'unique_values': array(['6.Workers in Agriculture, Livestock, Forestry, and Fishing',
#          '18.Safety and Security Personnel', nan,
#          '8.Artisans and Workers in Production, Repair, Maintenance',
#          '14.Merchants and Sales Representatives', '17.Domestic Workers',
#          '9.Operators of Fixed Machinery and Equipment for Ind. Production',
#          '15.Traveling Salespeople and Traveling Salespeople of Services',
#          '16.Workers in the Service Industry',
#          '4.Workers in Art, Shows, and Sports', '3.Educators',
#          '12.Department Heads/Coordinators/Supervisors in Admin and Service Activities',
#          '10.Asst/Laborers etc in Ind. Production, Repair, Maintenance',
#          '1.Professionals', '13.Administrative Support Staff',
#          '11.Drivers and Asst Drivers of Mobile Machinery and Transport Vehicles',
#          '7.Bosses/Supervisors etc in Artistic, Ind. Production, Repair, Maintenance Activities',
#          '2.Technicians',
#          '5.Officials and Directors Public, Private, and Social Sectors'],
#         dtype=object)},
#  'rjob_end_12': {'missing_percentage': 85.56166056166056,
#   'unique_values': array([  nan, 2007., 1962., 2010., 2012., 1995., 1987., 2005., 2003.,
#          2008., 1996., 1950., 2004., 1994., 1949., 2000., 1992., 1989.,
#          1963., 2001., 2011., 1952., 1984., 1980., 1988., 1964., 2006.,
#          1960., 1946., 2009., 1973., 1990., 1959., 1961., 1972., 1970.,
#          1971., 1979., 1982., 1977., 2002., 1958., 1998., 1978., 1974.,
#          1991., 1945., 1968., 1954., 1997., 1948., 1967., 1993., 1983.,
#          1951., 1935., 1986., 1965., 1947., 1955., 1981., 1969., 1975.,
#          1944., 1976., 1956., 1999., 1966., 1943., 1957., 1941., 1985.])},
#  'rjobend_reason_12': {'missing_percentage': 85.1037851037851,
#   'unique_values': array([nan, '8.Other', '3.Laid off', '4.Health reason', '5.Family reason',
#          '1.Retired'], dtype=object)},
#  'rearnings_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([      0.,   70000.,   10000.,   30000.,   50000.,   20000.,
#            60000.,  100000.,  290000.,   80000.,      nan,  150000.,
#            40000.,  190000.,  110000.,  120000., 1030000.,   90000.,
#           460000.,  200000.,  360000.,  140000.,  430000.,  300000.,
#           180000.,  130000.,  810000.,  170000., 1160000.,  250000.,
#           610000.,  580000.,  240000.,  740000.,  270000.,  220000.,
#           280000.,  720000.,  420000.,  690000.,  680000.,  160000.,
#           260000.,  210000.,  310000.])},
#  'searnings_12': {'missing_percentage': 36.17216117216117,
#   'unique_values': array([      0.,      nan,  160000.,   60000.,   50000.,  100000.,
#          1370000.,   40000.,   70000.,   30000.,   20000.,   10000.,
#           140000.,   80000.,  110000.,  210000.,  240000.,  130000.,
#            90000.,  300000.,  180000.,  250000.,  120000.,  790000.,
#           190000.,  450000.,  170000.,  350000.,  320000.,  530000.,
#           280000.,  220000.,  150000.,  610000.,  430000.,  310000.,
#          1030000.,  680000.])},
#  'hincome_12': {'missing_percentage': 4.212454212454213,
#   'unique_values': array([ 1.400e+05,  7.000e+04,  0.000e+00,  1.000e+04,  3.000e+04,
#           8.000e+04, -3.000e+04,  1.600e+05,  6.000e+04,  2.500e+05,
#           1.100e+05,  5.000e+04,  1.700e+05,  2.000e+04,  4.000e+04,
#           1.000e+05,  9.000e+04,  1.200e+05,  1.300e+05, -1.000e+04,
#           2.900e+05,        nan,  1.520e+06,  1.800e+05,  5.000e+05,
#           3.600e+05,  9.100e+05,  2.700e+05,  2.800e+05,  1.500e+05,
#           1.900e+05,  1.060e+06,  2.400e+05,  2.000e+05,  3.300e+05,
#           1.030e+06,  2.200e+05,  2.300e+05,  6.200e+05,  4.700e+05,
#           3.800e+05,  2.600e+05,  1.230e+06,  2.100e+05,  6.100e+05,
#           1.110e+06,  4.900e+05,  8.700e+05,  1.080e+06,  7.200e+05,
#           4.300e+05,  3.400e+05,  3.000e+05,  1.810e+06,  6.000e+05,
#          -1.900e+05,  1.200e+06,  2.050e+06,  3.700e+05,  9.800e+05,
#           3.602e+07,  7.900e+05,  1.050e+06,  2.400e+06,  4.800e+05,
#           1.000e+06,  6.900e+05,  3.200e+05,  1.170e+06,  4.500e+05,
#           1.590e+06,  6.500e+05,  5.500e+05,  4.200e+05,  3.500e+05,
#           6.400e+05,  1.650e+06,  3.100e+05,  1.160e+06,  4.000e+05,
#           5.530e+06,  5.800e+05, -1.500e+05,  3.900e+05,  5.300e+05,
#           2.290e+06,  1.420e+06,  6.020e+06,  1.480e+06, -9.000e+04,
#           6.300e+05,  1.210e+06,  7.400e+05,  1.070e+06, -2.000e+04,
#           4.300e+06,  5.900e+05,  9.600e+05,  6.800e+05,  1.140e+06,
#           8.600e+05, -5.000e+04,  5.100e+05,  8.300e+05,  5.700e+05,
#           6.600e+05,  1.440e+06,  2.270e+06])},
#  'hinc_business_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([1.00e+04, 0.00e+00, 2.40e+05, 1.10e+05, 4.00e+04,      nan,
#          3.00e+04, 1.80e+05, 4.90e+05, 3.60e+05, 9.10e+05, 2.00e+04,
#          1.00e+05, 6.00e+04, 7.00e+04, 1.05e+06, 8.40e+05, 3.30e+05,
#          4.10e+05, 1.50e+05, 1.90e+05, 8.00e+04, 4.30e+05, 1.07e+06,
#          7.20e+05, 5.00e+04, 1.20e+05, 1.80e+06, 1.60e+05, 2.05e+06,
#          3.60e+07, 9.80e+05, 4.40e+05, 1.38e+06, 1.59e+06, 6.00e+05,
#          1.43e+06, 1.40e+05, 3.70e+05, 1.20e+06, 2.29e+06, 7.90e+05,
#          1.37e+06, 1.02e+06, 3.50e+05, 1.27e+06, 9.60e+05, 2.00e+05,
#          5.80e+05, 1.52e+06, 5.90e+05, 1.70e+05, 4.80e+05, 1.14e+06,
#          2.30e+05, 9.00e+04, 6.10e+05, 3.00e+05, 1.65e+06, 1.44e+06,
#          2.24e+06])},
#  'hinc_rent_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([      0.,  -60000.,  -10000.,   90000.,      nan,   10000.,
#            20000.,   60000.,  -40000.,  340000.,   40000.,  840000.,
#          -360000.,   50000.,  -20000., -210000., 1200000., -160000.,
#          -140000.,  100000.,  540000., -170000.,   80000.,   30000.,
#          -120000.,  400000.,  -50000.,  110000., -180000.,  -80000.,
#           170000.,   70000.,  -30000.])},
#  'hinc_assets_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([     0.,     nan,   8000., 232000.,  22000.,   6000.,   1000.,
#           91000.,  19000.,  89000.,  31000., 129000.,  93000.,  15000.,
#          105000.,  72000.,  12000.,  36000.,  41000.,  11000., 103000.,
#           16000., 180000.,   7000.,   2000.,  20000.,  17000.,   5000.,
#           73000.,  98000.,  74000.,  24000.,  42000.,  60000., 360000.,
#           14000.,   4000.])},
#  'hinc_cap_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([ 1.00e+04,  0.00e+00, -6.00e+04,  2.40e+05,  1.10e+05, -1.00e+04,
#           4.00e+04,  9.00e+04,       nan,  3.00e+04,  1.80e+05,  4.90e+05,
#           3.60e+05,  9.10e+05,  2.30e+05,  2.00e+04,  1.00e+05,  6.00e+04,
#           7.00e+04,  1.05e+06,  8.40e+05,  3.30e+05,  4.10e+05,  1.50e+05,
#           1.90e+05, -4.00e+04,  8.00e+04,  3.40e+05,  4.30e+05,  1.07e+06,
#           1.30e+05,  5.00e+04,  1.20e+05,  1.80e+06,  1.60e+05, -2.00e+04,
#          -2.10e+05,  1.20e+06,  2.05e+06,  3.60e+07,  9.80e+05,  4.40e+05,
#           1.22e+06,  1.59e+06,  6.00e+05,  1.43e+06, -1.40e+05,  1.40e+05,
#           5.80e+05, -1.70e+05,  3.70e+05,  2.29e+06,  7.90e+05,  1.37e+06,
#           1.02e+06,  3.50e+05,  1.46e+06,  9.60e+05, -1.20e+05,  7.20e+05,
#          -5.00e+04,  1.52e+06,  5.90e+05,  1.70e+05,  2.70e+05,  4.80e+05,
#           1.14e+06, -3.00e+04,  6.10e+05,  3.00e+05,  1.65e+06,  1.44e+06,
#           2.24e+06])},
#  'rinc_pension_12': {'missing_percentage': 2.716727716727717,
#   'unique_values': array([     0.,  30000., 170000.,  20000.,  10000.,  70000.,     nan,
#           60000.,  50000.,  80000.,  40000., 120000., 100000., 200000.,
#          130000., 150000., 240000., 110000., 720000., 220000., 260000.,
#          600000., 960000., 140000., 480000., 190000., 430000., 360000.,
#           90000., 250000., 230000., 180000., 160000., 310000., 320000.,
#          290000., 300000.])},
#  'sinc_pension_12': {'missing_percentage': 36.17216117216117,
#   'unique_values': array([      0.,      nan,   30000.,   40000.,   10000.,  120000.,
#            20000.,   80000.,  240000.,  200000.,  100000.,   70000.,
#            60000.,   50000.,  480000.,  190000.,  140000.,  160000.,
#           110000.,  170000.,  340000.,  150000.,  130000.,  180000.,
#          1200000.,   90000.,  220000.,  360000.,  260000.,  280000.,
#           600000.,  230000.])},
#  'rrelgimp_12': {'missing_percentage': 6.7765567765567765,
#   'unique_values': array(['2.somewhat important', '1.very important', '3.not important', nan],
#         dtype=object)},
#  'rrfcntx_m_12': {'missing_percentage': 6.868131868131869,
#   'unique_values': array(['9.Never', '6.2 or 3 times a month', '4.Once a week',
#          '3.2 or 3 times a week', '8.Almost Never, sporadic',
#          '1.Almost every day', '2.4 or more times a week', '7.Once a month',
#          nan, '5.4 or more times a month'], dtype=object)},
#  'rsocact_m_12': {'missing_percentage': 6.593406593406594,
#   'unique_values': array(['9.Never', '1.Almost every day', '2.4 or more times a week',
#          '3.2 or 3 times a week', '4.Once a week', '7.Once a month',
#          '8.Almost Never, sporadic', nan, '6.2 or 3 times a month',
#          '5.4 or more times a month'], dtype=object)},
#  'rrelgwk_12': {'missing_percentage': 6.654456654456655,
#   'unique_values': array(['0.No', '1.Yes', nan], dtype=object)},
#  'a16a_12': {'missing_percentage': 99.26739926739927,
#   'unique_values': array([  nan, 1978., 1987., 1965., 1960., 1970., 1951., 2002., 1975.,
#          1993., 2012., 1962., 1976., 2010., 2005., 1957., 1945., 1985.,
#          1942., 1964., 1958., 1969.])},
#  'a21_12': {'missing_percentage': 98.71794871794873,
#   'unique_values': array([nan,  1., 52.,  3., 40., 15.,  7.,  2., 30.,  4.,  5.,  6., 36.,
#          10., 27., 34.])},
#  'a22_12': {'missing_percentage': 98.9010989010989,
#   'unique_values': array([nan, 'Agriculture/ Animal breeding 01',
#          'Gardening or maintenance 03',
#          'Construction/ Manufacturing/ Mining 02', 'Did not work 08',
#          'Childcare or domestic work 04', 'Restaurant/ Store/ Hotel 05',
#          'Other 07'], dtype=object)},
#  'a33b_12': {'missing_percentage': 98.71794871794873,
#   'unique_values': array([nan, 'Neither 3', 'Permanent resident 1', 'Citizen 2'],
#         dtype=object)},
#  'a34_12': {'missing_percentage': 35.53113553113553,
#   'unique_values': array([nan, 'No 2', 'Yes 1'], dtype=object)},
#  'j11_12': {'missing_percentage': 2.2893772893772892,
#   'unique_values': array(['Concrete 2', 'Wood, mosaic, or other covering 1', 'Mud 3', nan],
#         dtype=object)}}

# %% [markdown]
# - Total Columns with Missing Values: 197 out of all the columns in train_features.csv.
# - Range of Missing Percentages: From as low as ~2.29% to as high as ~99.27%.
# - Categories of Missingness:
#     - Low Missingness (<10%): Generally recent data from 2012 (_12 variables).
#     - Moderate Missingness (10%-50%): Mix of 2003 (_03) and 2012 (_12) variables.
#     - High Missingness (>50%): Mostly variables from 2003 (_03), especially occupation-related data.

# %% [markdown]
# To prepare for different strategies in handling missing data, we'll separate the variables into four categories based on their percentage of missing values:
#
# 1. Low Missingness: Variables with missing values less than or equal to 10%.
# 2. Moderate Missingness: Variables with missing values greater than 10% and less than or equal to 50%.
# 3. High Missingness: Variables with missing values greater than 50%, and less than 90%
# 4. Very High Missingness: Variables with missing values greater than 90%

# %%
# Define thresholds for missingness categories
low_threshold = 10       # 10% or less is considered low missingness
moderate_threshold = 50  # Between 10% and 50% is moderate missingness
high_threshold = 90      # Between 50% and 90% is high missingness

# Separate columns based on missingness percentages
low_missingness_columns = missing_values_features[missing_values_features <= low_threshold].index.tolist()
moderate_missingness_columns = missing_values_features[
    (missing_values_features > low_threshold) & (missing_values_features <= moderate_threshold)
].index.tolist()
high_missingness_columns = missing_values_features[
    (missing_values_features > moderate_threshold) & (missing_values_features <= high_threshold)
].index.tolist()
very_high_missingness_columns = missing_values_features[missing_values_features > high_threshold].index.tolist()

# Print the number of variables in each category
print(f"Low missingness columns ({len(low_missingness_columns)}): {low_missingness_columns}\n")
print(f"Moderate missingness columns ({len(moderate_missingness_columns)}): {moderate_missingness_columns}\n")
print(f"High missingness columns ({len(high_missingness_columns)}): {high_missingness_columns}\n")
print(f"Very high missingness columns ({len(very_high_missingness_columns)}): {very_high_missingness_columns}\n")
# Out:
# Low missingness columns (93): ['uid', 'age_12', 'urban_12', 'married_12', 'n_mar_12', 'edu_gru_12', 'n_living_child_12', 'migration_12', 'glob_hlth_12', 'adl_dress_12', 'adl_walk_12', 'adl_bath_12', 'adl_eat_12', 'adl_bed_12', 'adl_toilet_12', 'n_adl_12', 'iadl_money_12', 'iadl_meds_12', 'iadl_shop_12', 'iadl_meals_12', 'n_iadl_12', 'depressed_12', 'hard_12', 'restless_12', 'happy_12', 'lonely_12', 'enjoy_12', 'sad_12', 'tired_12', 'energetic_12', 'n_depr_12', 'cesd_depressed_12', 'hypertension_12', 'diabetes_12', 'resp_ill_12', 'arthritis_12', 'hrt_attack_12', 'stroke_12', 'cancer_12', 'n_illnesses_12', 'exer_3xwk_12', 'alcohol_12', 'tobacco_12', 'test_chol_12', 'test_tuber_12', 'test_diab_12', 'test_pres_12', 'hosp_12', 'visit_med_12', 'out_proc_12', 'visit_dental_12', 'imss_12', 'issste_12', 'pem_def_mar_12', 'insur_private_12', 'insur_other_12', 'insured_12', 'decis_personal_12', 'employment_12', 'vax_flu_12', 'vax_pneu_12', 'seg_pop_12', 'care_adult_12', 'care_child_12', 'volunteer_12', 'attends_class_12', 'attends_club_12', 'reads_12', 'games_12', 'table_games_12', 'comms_tel_comp_12', 'act_mant_12', 'tv_12', 'sewing_12', 'satis_ideal_12', 'satis_excel_12', 'satis_fine_12', 'cosas_imp_12', 'wouldnt_change_12', 'memory_12', 'ragender', 'rearnings_12', 'hincome_12', 'hinc_business_12', 'hinc_rent_12', 'hinc_assets_12', 'hinc_cap_12', 'rinc_pension_12', 'rrelgimp_12', 'rrfcntx_m_12', 'rsocact_m_12', 'rrelgwk_12', 'j11_12']
#
# Moderate missingness columns (78): ['age_03', 'urban_03', 'married_03', 'n_mar_03', 'edu_gru_03', 'n_living_child_03', 'migration_03', 'glob_hlth_03', 'adl_dress_03', 'adl_walk_03', 'adl_bath_03', 'adl_eat_03', 'adl_bed_03', 'adl_toilet_03', 'n_adl_03', 'iadl_money_03', 'iadl_meds_03', 'iadl_shop_03', 'iadl_meals_03', 'n_iadl_03', 'depressed_03', 'hard_03', 'restless_03', 'happy_03', 'lonely_03', 'enjoy_03', 'sad_03', 'tired_03', 'energetic_03', 'n_depr_03', 'cesd_depressed_03', 'hypertension_03', 'diabetes_03', 'resp_ill_03', 'arthritis_03', 'hrt_attack_03', 'stroke_03', 'cancer_03', 'n_illnesses_03', 'exer_3xwk_03', 'alcohol_03', 'tobacco_03', 'test_chol_03', 'test_tuber_03', 'test_diab_03', 'test_pres_03', 'hosp_03', 'visit_med_03', 'out_proc_03', 'visit_dental_03', 'imss_03', 'issste_03', 'pem_def_mar_03', 'insur_private_03', 'insur_other_03', 'insured_03', 'decis_personal_03', 'employment_03', 'bmi_12', 'decis_famil_12', 'rameduc_m', 'rafeduc_m', 'sgender_03', 'rearnings_03', 'searnings_03', 'hincome_03', 'hinc_business_03', 'hinc_rent_03', 'hinc_assets_03', 'hinc_cap_03', 'rinc_pension_03', 'sinc_pension_03', 'rrelgimp_03', 'sgender_12', 'rjlocc_m_12', 'searnings_12', 'sinc_pension_12', 'a34_12']
#
# High missingness columns (8): ['bmi_03', 'decis_famil_03', 'rjob_hrswk_03', 'rjob_end_03', 'rjobend_reason_03', 'rjob_hrswk_12', 'rjob_end_12', 'rjobend_reason_12']
#
# Very high missingness columns (5): ['rjlocc_m_03', 'a16a_12', 'a21_12', 'a22_12', 'a33b_12']

# %% [markdown]
# For low missingness columns, we can use simple imputation methods like mean (for numerical variables) or mode (for categorical variables).

# %%
# Get the data types of the columns
column_types = train_features.dtypes

# Identify numerical and categorical columns
numerical_columns = column_types[column_types != 'object'].index.tolist()
categorical_columns = column_types[column_types == 'object'].index.tolist()

# Now, among the low missingness columns, separate numerical and categorical
low_missing_numerical = [col for col in low_missingness_columns if col in numerical_columns]
low_missing_categorical = [col for col in low_missingness_columns if col in categorical_columns]

# Impute numerical columns with mean
for col in low_missing_numerical:
    mean_value = train_features[col].mean()
    train_features[col].fillna(mean_value, inplace=True)

# Impute categorical columns with mode
for col in low_missing_categorical:
    mode_value = train_features[col].mode()
    if not mode_value.empty:
        mode_value = mode_value[0]
        train_features[col].fillna(mode_value, inplace=True)
    else:
        # If mode is empty (all values are NaN), fill with a placeholder or keep NaN
        train_features[col].fillna('Unknown', inplace=True)

# Verify that there are no missing values in low missingness columns
missing_after_imputation = train_features[low_missingness_columns].isnull().sum()
print("Missing values after imputation in low missingness columns:")
print(missing_after_imputation)
# Out:
# Missing values after imputation in low missingness columns:
# uid             0
# age_12          0
# urban_12        0
# married_12      0
# n_mar_12        0
#                ..
# rrelgimp_12     0
# rrfcntx_m_12    0
# rsocact_m_12    0
# rrelgwk_12      0
# j11_12          0
# Length: 93, dtype: int64

# %% [markdown]
# For moderate misssingness columns, for categorical variables, we can introduce a new category 'Missing' and for numerical variables, we can create a missingness indicator and impute missing values with the median

# %%
# Separate numerical and categorical columns among moderate missingness columns
moderate_missing_numerical = [col for col in moderate_missingness_columns if column_types[col] != 'object']
moderate_missing_categorical = [col for col in moderate_missingness_columns if column_types[col] == 'object']

# For categorical variables, replace missing values with a new category 'Missing'
for col in moderate_missing_categorical:
    train_features[col] = train_features[col].fillna('Missing')

# For numerical variables, we'll create a missingness indicator and impute missing values with the median

for col in moderate_missing_numerical:
    # Create missingness indicator
    train_features[f'{col}_missing'] = train_features[col].isnull().astype(int)
    # Impute missing values with the median
    median_value = train_features[col].median()
    train_features[col].fillna(median_value, inplace=True)

# Verify that missing values have been handled in moderate missingness columns
missing_after_imputation = train_features[moderate_missingness_columns].isnull().sum()
print("Missing values after handling in moderate missingness columns:")
print(missing_after_imputation)
# Out:
# Missing values after handling in moderate missingness columns:
# age_03             0
# urban_03           0
# married_03         0
# n_mar_03           0
# edu_gru_03         0
#                   ..
# sgender_12         0
# rjlocc_m_12        0
# searnings_12       0
# sinc_pension_12    0
# a34_12             0
# Length: 78, dtype: int64

# %% [markdown]
# Potential Issues:
#
# 1. Multicollinearity:
#
# - Including both the original variable (with imputed values) and the missingness indicator could introduce multicollinearity.
# - Consider assessing variance inflation factors (VIF) if multicollinearity is a concern.
# 2. Model Compatibility:
#
# - Some machine learning algorithms can handle missing values internally (e.g., decision trees in certain implementations). However, creating missingness indicators and imputing ensures compatibility across different models.

# %% [markdown]
# Since columns with high (>50%) and very high (>90%) missingness contain a significant proportion of missing data, it's reasonable to consider dropping them out of our dataset.

# %%
# Combine high and very high missingness columns
columns_to_drop = high_missingness_columns + very_high_missingness_columns

# Drop these columns from the DataFrame
train_features_dropped = train_features.drop(columns=columns_to_drop)

# Print the number of columns before and after dropping
print(f"Number of columns before dropping: {train_features.shape[1]}")
print(f"Number of columns after dropping: {train_features_dropped.shape[1]}")
# Out:
# Number of columns before dropping: 246
# Number of columns after dropping: 233

# %% [markdown]
# Next we deal with categorical variables. We need to identify ordinal and nominal variables and encode them appropriately.

# %%
# Get data types of all columns
data_types = train_features_dropped.dtypes

# Identify categorical variables (object type or categorical type)
categorical_columns = data_types[data_types == 'object'].index.tolist()

print(f"Categorical variables ({len(categorical_columns)}): {categorical_columns}")
# Out:
# Categorical variables (37): ['uid', 'age_03', 'urban_03', 'married_03', 'edu_gru_03', 'n_living_child_03', 'glob_hlth_03', 'employment_03', 'age_12', 'urban_12', 'married_12', 'edu_gru_12', 'n_living_child_12', 'glob_hlth_12', 'bmi_12', 'decis_famil_12', 'decis_personal_12', 'employment_12', 'satis_ideal_12', 'satis_excel_12', 'satis_fine_12', 'cosas_imp_12', 'wouldnt_change_12', 'memory_12', 'ragender', 'rameduc_m', 'rafeduc_m', 'sgender_03', 'rrelgimp_03', 'sgender_12', 'rjlocc_m_12', 'rrelgimp_12', 'rrfcntx_m_12', 'rsocact_m_12', 'rrelgwk_12', 'a34_12', 'j11_12']

# %%
# Identify ordinal variables based on data descriptions
ordinal_variables = [
    'age_03',              # Binned age group
    'edu_gru_03',          # Binned education level
    'n_living_child_03',   # Binned number of living children
    'glob_hlth_03',        # Self-reported global health
    'age_12',              # Binned age group
    'edu_gru_12',          # Binned education level
    'n_living_child_12',   # Binned number of living children
    'glob_hlth_12',        # Self-reported global health
    'bmi_12',              # Binned body mass index
    'decis_famil_12',      # Weight in family decisions
    'decis_personal_12',   # Weight over personal decisions
    'satis_ideal_12',      # Agreement with life satisfaction statements
    'satis_excel_12',
    'satis_fine_12',
    'cosas_imp_12',
    'wouldnt_change_12',
    'memory_12',           # Self-reported memory
    'rameduc_m',           # Mother's education level
    'rafeduc_m',           # Father's education level
    'rrelgimp_03',         # Importance of religion
    'rrelgimp_12',
    'rrfcntx_m_12',        # Frequency of seeing friends/relatives
    'rsocact_m_12',        # Frequency of social activities
    'rrelgwk_12',          # Participation in weekly religious services
    'a34_12'               # English proficiency
]

# Nominal variables are the rest of the categorical variables
nominal_variables = [col for col in categorical_columns if col not in ordinal_variables]

# Output the lists
print(f"Ordinal variables ({len(ordinal_variables)}): {ordinal_variables}\n")
print(f"Nominal variables ({len(nominal_variables)}): {nominal_variables}\n")
# Out:
# Ordinal variables (25): ['age_03', 'edu_gru_03', 'n_living_child_03', 'glob_hlth_03', 'age_12', 'edu_gru_12', 'n_living_child_12', 'glob_hlth_12', 'bmi_12', 'decis_famil_12', 'decis_personal_12', 'satis_ideal_12', 'satis_excel_12', 'satis_fine_12', 'cosas_imp_12', 'wouldnt_change_12', 'memory_12', 'rameduc_m', 'rafeduc_m', 'rrelgimp_03', 'rrelgimp_12', 'rrfcntx_m_12', 'rsocact_m_12', 'rrelgwk_12', 'a34_12']
#
# Nominal variables (12): ['uid', 'urban_03', 'married_03', 'employment_03', 'urban_12', 'married_12', 'employment_12', 'ragender', 'sgender_03', 'sgender_12', 'rjlocc_m_12', 'j11_12']

# %%
train_features_dropped['edu_gru_12'].unique()
# Out:
# array(['0. No education', '3. 7–9 years', '1. 1–5 years', '2. 6 years',
#        '4. 10+ years'], dtype=object)

# %%
# Mappings for ordinal variables

# age_03 and age_12: Binned age group
age_mapping = {
    '0. 49 or younger': 0,
    '1. 50–59': 1,
    '2. 60–69': 2,
    '3. 70–79': 3,
    '4. 80+': 4,
    'Missing': np.nan  # or choose an appropriate code for missing values
}


# edu_gru_03 and edu_gru_12: Binned education level
education_mapping = {
    '0. No education': 0,
    '1. 1–5 years': 1,
    '2. 6 years': 2,
    '3. 7–9 years': 3,
    '4. 10+ years': 4,
    'Missing': np.nan
}


# n_living_child_03 and n_living_child_12: Binned number of living children
n_living_child_mapping = {
    '0. No children': 0,
    '1. 1 or 2': 1,
    '2. 3 or 4': 2,
    '3. 5 or 6': 3,
    '4. 7+': 4,
    'Missing': np.nan
}


# glob_hlth_03 and glob_hlth_12: Self-reported global health
glob_health_mapping = {
    '1. Excellent': 5,
    '2. Very good': 4,
    '3. Good': 3,
    '4. Fair': 2,
    '5. Poor': 1,
    'Missing': np.nan
}


# bmi_12: Binned body mass index
bmi_mapping = {
    '1. Underweight': 1,
    '2. Normal weight': 2,
    '3. Overweight': 3,
    '4. Obese': 4,
    '5. Morbidly obese': 5,
    'Missing': np.nan
}


# decis_famil_12 Weight in family decisions
decis_famil_mapping = {
    '1. Respondent': 1,
    '2. Approximately equal weight': 2,
    '3. Spouse': 3,
    'Missing': np.nan
}

# decis_personal_12 Weight in personal decisions
decis_personal_mapping = {
    '1. A lot': 3,
    '2. A little': 2,
    '3. None': 1
}

# satis_ideal_12, satis_excel_12, satis_fine_12, cosas_imp_12, wouldnt_change_12:
# Agreement with life satisfaction statements
agreement_mapping = {
    '1. Agrees': 3,
    '2. Neither agrees nor disagrees': 2,
    '3. Disagrees': 1,
    'Missing': np.nan
}


# memory_12: Self-reported memory
memory_mapping = {
    '1. Excellent': 5,
    '2. Very good': 4,
    '3. Good': 3,
    '4. Fair': 2,
    '5. Poor': 1,
    'Missing': np.nan
}


# rameduc_m and rafeduc_m: Mother's and Father's education level
parent_education_mapping = {
    '1.None': 1,
    '2.Some primary': 2,
    '3.Primary': 3,
    '4.More than primary': 4,
    'Missing': np.nan
}


# rrelgimp_03 and rrelgimp_12: Importance of religion
religion_importance_mapping = {
    '1.very important': 3,
    '2.somewhat important': 2,
    '3.not important': 1,
    'Missing': np.nan
}


# rrfcntx_m_12 and rsocact_m_12: Frequency of social interactions
frequency_mapping = {
    '1.Almost every day': 9,
    '2.4 or more times a week': 8,
    '3.2 or 3 times a week': 7,
    '4.Once a week': 6,
    '5.4 or more times a month': 5,
    '6.2 or 3 times a month': 4,
    '7.Once a month': 3,
    '8.Almost Never, sporadic': 2,
    '9.Never': 1,
    'Missing': np.nan
}


# rrelgwk_12: Participation in weekly religious services
religious_services_mapping = {
    '1.Yes': 1,
    '0.No': 0,
    'Missing': np.nan
}


# 13. a34_12: English proficiency
english_proficiency_mapping = {
    'Yes 1': 1,
    'No 2': 0,
    'Missing': np.nan
}

# Compile all mappings into a dictionary for easy access
ordinal_mappings = {
    'age_03': age_mapping,
    'age_12': age_mapping,
    'edu_gru_03': education_mapping,
    'edu_gru_12': education_mapping,
    'n_living_child_03': n_living_child_mapping,
    'n_living_child_12': n_living_child_mapping,
    'glob_hlth_03': glob_health_mapping,
    'glob_hlth_12': glob_health_mapping,
    'bmi_12': bmi_mapping,
    'decis_famil_12': decis_famil_mapping,
    'decis_personal_12': decis_personal_mapping,
    'satis_ideal_12': agreement_mapping,
    'satis_excel_12': agreement_mapping,
    'satis_fine_12': agreement_mapping,
    'cosas_imp_12': agreement_mapping,
    'wouldnt_change_12': agreement_mapping,
    'memory_12': memory_mapping,
    'rameduc_m': parent_education_mapping,
    'rafeduc_m': parent_education_mapping,
    'rrelgimp_03': religion_importance_mapping,
    'rrelgimp_12': religion_importance_mapping,
    'rrfcntx_m_12': frequency_mapping,
    'rsocact_m_12': frequency_mapping,
    'rrelgwk_12': religious_services_mapping,
    'a34_12': english_proficiency_mapping
}

# Print out the mappings
for var, mapping in ordinal_mappings.items():
    print(f"Mapping for {var}:")
    for category, code in mapping.items():
        print(f"  '{category}': {code}")
    print()
# Out:
# Mapping for age_03:
#   '0. 49 or younger': 0
#   '1. 50–59': 1
#   '2. 60–69': 2
#   '3. 70–79': 3
#   '4. 80+': 4
#   'Missing': nan
#
# Mapping for age_12:
#   '0. 49 or younger': 0
#   '1. 50–59': 1
#   '2. 60–69': 2
#   '3. 70–79': 3
#   '4. 80+': 4
#   'Missing': nan
#
# Mapping for edu_gru_03:
#   '0. No education': 0
#   '1. 1–5 years': 1
#   '2. 6 years': 2
#   '3. 7–9 years': 3
#   '4. 10+ years': 4
#   'Missing': nan
#
# Mapping for edu_gru_12:
#   '0. No education': 0
#   '1. 1–5 years': 1
#   '2. 6 years': 2
#   '3. 7–9 years': 3
#   '4. 10+ years': 4
#   'Missing': nan
#
# Mapping for n_living_child_03:
#   '0. No children': 0
#   '1. 1 or 2': 1
#   '2. 3 or 4': 2
#   '3. 5 or 6': 3
#   '4. 7+': 4
#   'Missing': nan
#
# Mapping for n_living_child_12:
#   '0. No children': 0
#   '1. 1 or 2': 1
#   '2. 3 or 4': 2
#   '3. 5 or 6': 3
#   '4. 7+': 4
#   'Missing': nan
#
# Mapping for glob_hlth_03:
#   '1. Excellent': 5
#   '2. Very good': 4
#   '3. Good': 3
#   '4. Fair': 2
#   '5. Poor': 1
#   'Missing': nan
#
# Mapping for glob_hlth_12:
#   '1. Excellent': 5
#   '2. Very good': 4
#   '3. Good': 3
#   '4. Fair': 2
#   '5. Poor': 1
#   'Missing': nan
#
# Mapping for bmi_12:
#   '1. Underweight': 1
#   '2. Normal weight': 2
#   '3. Overweight': 3
#   '4. Obese': 4
#   '5. Morbidly obese': 5
#   'Missing': nan
#
# Mapping for decis_famil_12:
#   '1. Respondent': 1
#   '2. Approximately equal weight': 2
#   '3. Spouse': 3
#   'Missing': nan
#
# Mapping for decis_personal_12:
#   '1. A lot': 3
#   '2. A little': 2
#   '3. None': 1
#
# Mapping for satis_ideal_12:
#   '1. Agrees': 3
#   '2. Neither agrees nor disagrees': 2
#   '3. Disagrees': 1
#   'Missing': nan
#
# Mapping for satis_excel_12:
#   '1. Agrees': 3
#   '2. Neither agrees nor disagrees': 2
#   '3. Disagrees': 1
#   'Missing': nan
#
# Mapping for satis_fine_12:
#   '1. Agrees': 3
#   '2. Neither agrees nor disagrees': 2
#   '3. Disagrees': 1
#   'Missing': nan
#
# Mapping for cosas_imp_12:
#   '1. Agrees': 3
#   '2. Neither agrees nor disagrees': 2
#   '3. Disagrees': 1
#   'Missing': nan
#
# Mapping for wouldnt_change_12:
#   '1. Agrees': 3
#   '2. Neither agrees nor disagrees': 2
#   '3. Disagrees': 1
#   'Missing': nan
#
# Mapping for memory_12:
#   '1. Excellent': 5
#   '2. Very good': 4
#   '3. Good': 3
#   '4. Fair': 2
#   '5. Poor': 1
#   'Missing': nan
#
# Mapping for rameduc_m:
#   '1.None': 1
#   '2.Some primary': 2
#   '3.Primary': 3
#   '4.More than primary': 4
#   'Missing': nan
#
# Mapping for rafeduc_m:
#   '1.None': 1
#   '2.Some primary': 2
#   '3.Primary': 3
#   '4.More than primary': 4
#   'Missing': nan
#
# Mapping for rrelgimp_03:
#   '1.very important': 3
#   '2.somewhat important': 2
#   '3.not important': 1
#   'Missing': nan
#
# Mapping for rrelgimp_12:
#   '1.very important': 3
#   '2.somewhat important': 2
#   '3.not important': 1
#   'Missing': nan
#
# Mapping for rrfcntx_m_12:
#   '1.Almost every day': 9
#   '2.4 or more times a week': 8
#   '3.2 or 3 times a week': 7
#   '4.Once a week': 6
#   '5.4 or more times a month': 5
#   '6.2 or 3 times a month': 4
#   '7.Once a month': 3
#   '8.Almost Never, sporadic': 2
#   '9.Never': 1
#   'Missing': nan
#
# Mapping for rsocact_m_12:
#   '1.Almost every day': 9
#   '2.4 or more times a week': 8
#   '3.2 or 3 times a week': 7
#   '4.Once a week': 6
#   '5.4 or more times a month': 5
#   '6.2 or 3 times a month': 4
#   '7.Once a month': 3
#   '8.Almost Never, sporadic': 2
#   '9.Never': 1
#   'Missing': nan
#
# Mapping for rrelgwk_12:
#   '1.Yes': 1
#   '0.No': 0
#   'Missing': nan
#
# Mapping for a34_12:
#   'Yes 1': 1
#   'No 2': 0
#   'Missing': nan

# %%
# Check for unmapped categories in each ordinal variable
for var, mapping in ordinal_mappings.items():
    if var in train_features_dropped.columns:
        unique_values = set(train_features_dropped[var].unique())
        mapped_values = set(mapping.keys())
        unmapped_values = unique_values - mapped_values
        if unmapped_values:
            print(f"Unmapped categories in {var}: {unmapped_values}")

# %%
# Apply the mappings to the ordinal variables
for var, mapping in ordinal_mappings.items():
    if var in train_features_dropped.columns:
        # Map the ordinal variable using the specified mapping
        train_features_dropped[var] = train_features_dropped[var].map(mapping)
    else:
        print(f"Warning: {var} not found in the dataframe columns.")

# Handle missing values if needed
# For example, fill NaN values with the median of the column
for var in ordinal_mappings.keys():
    if var in train_features_dropped.columns:
        median_value = train_features_dropped[var].median()
        train_features_dropped[var].fillna(median_value, inplace=True)

# %%
# Check the unique values after encoding
for var in ordinal_mappings.keys():
    if var in train_features_dropped.columns:
        print(f"Unique values in {var} after encoding: {train_features_dropped[var].unique()}")
# Out:
# Unique values in age_03 after encoding: [1. 3. 2. 0. 4.]
# Unique values in age_12 after encoding: [2. 1. 4. 3. 0.]
# Unique values in edu_gru_03 after encoding: [1. 3. 0. 2. 4.]
# Unique values in edu_gru_12 after encoding: [0. 3. 1. 2. 4.]
# Unique values in n_living_child_03 after encoding: [3. 1. 0. 2. 4.]
# Unique values in n_living_child_12 after encoding: [1. 3. 0. 2. 4.]
# Unique values in glob_hlth_03 after encoding: [2. 1. 3. 5. 4.]
# Unique values in glob_hlth_12 after encoding: [2. 3. 4. 1. 5.]
# Unique values in bmi_12 after encoding: [3. 4. 2. 1. 5.]
# Unique values in decis_famil_12 after encoding: [2. 3. 1.]
# Unique values in decis_personal_12 after encoding: [3 2 1]
# Unique values in satis_ideal_12 after encoding: [1. 3. 2.]
# Unique values in satis_excel_12 after encoding: [1. 2. 3.]
# Unique values in satis_fine_12 after encoding: [3. 1. 2.]
# Unique values in cosas_imp_12 after encoding: [3. 2. 1.]
# Unique values in wouldnt_change_12 after encoding: [1. 3. 2.]
# Unique values in memory_12 after encoding: [4. 2. 3. 1. 5.]
# Unique values in rameduc_m after encoding: [1. 2. 3. 4.]
# Unique values in rafeduc_m after encoding: [1. 2. 4. 3.]
# Unique values in rrelgimp_03 after encoding: [3. 2. 1.]
# Unique values in rrelgimp_12 after encoding: [2. 3. 1.]
# Unique values in rrfcntx_m_12 after encoding: [1. 4. 6. 7. 2. 9. 8. 3. 5.]
# Unique values in rsocact_m_12 after encoding: [1. 9. 8. 7. 6. 3. 2. 4. 5.]
# Unique values in rrelgwk_12 after encoding: [0. 1.]
# Unique values in a34_12 after encoding: [0. 1.]

# %%
# Checking data types for each column in train_features to identify potential mismatches
train_features_dropped.dtypes
# Out:
# uid                         object
# age_03                     float64
# urban_03                    object
# married_03                  object
# n_mar_03                   float64
#                             ...
# hinc_cap_03_missing          int64
# rinc_pension_03_missing      int64
# sinc_pension_03_missing      int64
# searnings_12_missing         int64
# sinc_pension_12_missing      int64
# Length: 233, dtype: object

# %% [markdown]
# 1. Identifiers:
#
#     - uid is appropriately set as an object type, as it uniquely identifies each individual.
# 2. Categorical Variables:
#
#     - Columns like age_03, urban_03, married_03, and other demographic and descriptive variables are currently object types. These will need encoding for use in machine learning models.
#     - Categorical columns include some with ordinal information (e.g., age ranges, education levels) that might benefit from ordinal encoding to retain order.
# 3. Numerical Variables:
#
#     - Variables related to counts (e.g., n_mar_03, n_adl_03, n_iadl_03) and binary indicators (0 or 1) are appropriately represented as float64.
#     - Economic variables like hincome_12, hinc_business_12, and similar income-based columns are correctly identified as float64 but may need transformations due to skewness.

# %%
nominal_variables
# Out:
# ['uid',
#  'urban_03',
#  'married_03',
#  'employment_03',
#  'urban_12',
#  'married_12',
#  'employment_12',
#  'ragender',
#  'sgender_03',
#  'sgender_12',
#  'rjlocc_m_12',
#  'j11_12']

# %% [markdown]
# For the nominal variables, we can use pandas' get_dummies() function to perform one-hot encoding.

# %%
# Perform one-hot encoding on the nominal variables
train_encoded = pd.get_dummies(train_features_dropped, columns=nominal_variables, drop_first=False)

# Checking the number of columns after one-hot encoding
print(f"Number of columns after one-hot encoding: {train_encoded.shape[1]}")
# Out:
# Number of columns after one-hot encoding: 3550

# %%
# Identifying categorical variables by checking columns with 'object' data type in train_features
categorical_columns = train_features.select_dtypes(include=['object']).columns.tolist()
categorical_columns
# Out:
# ['uid',
#  'age_03',
#  'urban_03',
#  'married_03',
#  'edu_gru_03',
#  'n_living_child_03',
#  'glob_hlth_03',
#  'bmi_03',
#  'decis_famil_03',
#  'employment_03',
#  'age_12',
#  'urban_12',
#  'married_12',
#  'edu_gru_12',
#  'n_living_child_12',
#  'glob_hlth_12',
#  'bmi_12',
#  'decis_famil_12',
#  'decis_personal_12',
#  'employment_12',
#  'satis_ideal_12',
#  'satis_excel_12',
#  'satis_fine_12',
#  'cosas_imp_12',
#  'wouldnt_change_12',
#  'memory_12',
#  'ragender',
#  'rameduc_m',
#  'rafeduc_m',
#  'sgender_03',
#  'rjlocc_m_03',
#  'rjobend_reason_03',
#  'rrelgimp_03',
#  'sgender_12',
#  'rjlocc_m_12',
#  'rjobend_reason_12',
#  'rrelgimp_12',
#  'rrfcntx_m_12',
#  'rsocact_m_12',
#  'rrelgwk_12',
#  'a22_12',
#  'a33b_12',
#  'a34_12',
#  'j11_12']

# %% [markdown]
# The dataset includes the following categorical variables:
#
# 1. Demographic and Background Information:
#
#     - age_03, urban_03, married_03, edu_gru_03, n_living_child_03, glob_hlth_03, bmi_03, decis_famil_03, employment_03 (and their 2012 counterparts).
#     - Static demographics: ragender (gender), rameduc_m (mother’s education), and rafeduc_m (father’s education).
# 2. Health and Well-being:
#
#     - Self-reported variables like satis_ideal_12, satis_excel_12, memory_12, and glob_hlth_12 reflect self-perceived health or life satisfaction.
#     - Variables related to body mass (bmi_03, bmi_12), activity, and health coverage.
# 3. Employment and Socioeconomic Information:
#
#     - Employment specifics such as rjlocc_m_03 (job category), rjobend_reason_03 (reason for job end), rrelgimp_03 (religion importance), and similar 2012 counterparts.
# 4. Lifestyle and Social Interaction:
#
#     - Variables indicating social interactions (rrfcntx_m_12, rsocact_m_12) and household decision-making (decis_famil_12, decis_personal_12).
# 5. Migration and Residency:
#
#     - U.S. migration and residency status (a22_12, a33b_12), including whether individuals worked or lived in the U.S. and English proficiency (a34_12).
#
# These variables will require encoding for modeling, with particular attention to ordinal categories where ordering matters

# %%
# Creating Python lists for ordinal and nominal variables based on previous identification

# List of ordinal variables
ordinal_variables = [
    'age_03', 'age_12', 'edu_gru_03', 'edu_gru_12', 'glob_hlth_03', 'glob_hlth_12', 
    'bmi_03', 'bmi_12', 'n_depr_03', 'n_depr_12', 'satis_ideal_12', 'satis_excel_12', 
    'satis_fine_12', 'cosas_imp_12', 'wouldnt_change_12', 'decis_famil_03', 
    'decis_famil_12', 'decis_personal_12', 'rrelgimp_03', 'rrelgimp_12', 'rrfcntx_m_12', 
    'rsocact_m_12', 'memory_12'
]

# List of nominal variables
nominal_variables = [
    'uid', 'married_03', 'married_12', 'urban_03', 'urban_12', 'n_living_child_03', 
    'n_living_child_12', 'employment_03', 'employment_12', 'ragender', 'sgender_03', 
    'sgender_12', 'rameduc_m', 'rafeduc_m', 'rjlocc_m_03', 'rjobend_reason_03', 
    'rjlocc_m_12', 'rjobend_reason_12', 'imss_03', 'issste_03', 'pem_def_mar_03', 
    'a22_12', 'a33b_12', 'a34_12', 'j11_12'
]

# Display the lists to confirm creation
ordinal_variables, nominal_variables
# Out:
# (['age_03',
#   'age_12',
#   'edu_gru_03',
#   'edu_gru_12',
#   'glob_hlth_03',
#   'glob_hlth_12',
#   'bmi_03',
#   'bmi_12',
#   'n_depr_03',
#   'n_depr_12',
#   'satis_ideal_12',
#   'satis_excel_12',
#   'satis_fine_12',
#   'cosas_imp_12',
#   'wouldnt_change_12',
#   'decis_famil_03',
#   'decis_famil_12',
#   'decis_personal_12',
#   'rrelgimp_03',
#   'rrelgimp_12',
#   'rrfcntx_m_12',
#   'rsocact_m_12',
#   'memory_12'],
#  ['uid',
#   'married_03',
#   'married_12',
#   'urban_03',
#   'urban_12',
#   'n_living_child_03',
#   'n_living_child_12',
#   'employment_03',
#   'employment_12',
#   'ragender',
#   'sgender_03',
#   'sgender_12',
#   'rameduc_m',
#   'rafeduc_m',
#   'rjlocc_m_03',
#   'rjobend_reason_03',
#   'rjlocc_m_12',
#   'rjobend_reason_12',
#   'imss_03',
#   'issste_03',
#   'pem_def_mar_03',
#   'a22_12',
#   'a33b_12',
#   'a34_12',
#   'j11_12'])
